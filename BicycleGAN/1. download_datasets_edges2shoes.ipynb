# %%
import os

dataset = 'edges2shoes'
data_dir = './dataset/' + dataset + '/'

if not os.path.exists(data_dir): 
    os.makedirs(data_dir)
    file=dataset + '.tar.gz'
    print(file)
    url='https://people.eecs.berkeley.edu/~tinghuiz/projects/pix2pix/datasets/' + dataset + '.tar.gz'
    print(url)
    # !wget -N $url -O $file
    # !tar -zxvf $file -C $data_dir
    # !rm $file
# Out:
# edges2shoes.tar.gz
# https://people.eecs.berkeley.edu/~tinghuiz/projects/pix2pix/datasets/edges2shoes.tar.gz
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2018-07-05 06:06:23--  https://people.eecs.berkeley.edu/~tinghuiz/projects/pix2pix/datasets/edges2shoes.tar.gz
# Resolving people.eecs.berkeley.edu (people.eecs.berkeley.edu)... 128.32.189.73
# Connecting to people.eecs.berkeley.edu (people.eecs.berkeley.edu)|128.32.189.73|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2165283376 (2.0G) [application/x-gzip]
# Saving to: ‘edges2shoes.tar.gz’
#
# edges2shoes.tar.gz  100%[===================>]   2.02G  1.66MB/s    in 21m 2s
#
# 2018-07-05 06:27:26 (1.64 MB/s) - ‘edges2shoes.tar.gz’ saved [2165283376/2165283376]
#
# edges2shoes/
# edges2shoes/train/
# edges2shoes/train/10000_AB.jpg
# edges2shoes/train/10001_AB.jpg
# edges2shoes/train/10002_AB.jpg
# edges2shoes/train/10003_AB.jpg
# ...
