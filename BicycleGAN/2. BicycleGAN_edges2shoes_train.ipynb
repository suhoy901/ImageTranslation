# %% [markdown]
# # BicycleGAN
#
# ## 1. Import Libs

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader

from dataloader import Edges2handbags
import util
import os
import argparse

from model import *

CUDA = torch.cuda.is_available()

# %% [markdown]
# ## 2. Settings

# %%
parser = argparse.ArgumentParser([])

parser.add_argument('--root', required=False, default='./dataset/edges2shoes/edges2shoes')
parser.add_argument('--result_dir', default='result/edges2shoes')
parser.add_argument('--weight_dir', default='weight/edges2shoes')
parser.add_argument('--load_weight', type=bool, default=False)
parser.add_argument('--batch_size', type=int, default=2)
parser.add_argument('--test_size', type=int, default=20)
parser.add_argument('--test_img_num', type=int, default=5)
parser.add_argument('--img_size', type=int, default=128)
parser.add_argument('--num_epoch', type=int, default=100)
parser.add_argument('--save_every', type=int, default=1000)
parser.add_argument('--lr', type=float, default=0.0002)
parser.add_argument('--beta_1', type=float, default=0.5)
parser.add_argument('--beta_2', type=float, default=0.999)
parser.add_argument('--lambda_kl', type=float, default=0.01)
parser.add_argument('--lambda_img', type=int, default=10)
parser.add_argument('--lambda_z', type=float, default=0.5)
parser.add_argument('--z_dim', type=int, default=8)

params = parser.parse_args([])
print(params)
# Out:
# Namespace(batch_size=2, beta_1=0.5, beta_2=0.999, img_size=128, lambda_img=10, lambda_kl=0.01, lambda_z=0.5, load_weight=False, lr=0.0002, num_epoch=100, result_dir='result/edges2shoes', root='./dataset/edges2shoes/edges2shoes', save_every=1000, test_img_num=5, test_size=20, weight_dir='weight/edges2shoes', z_dim=8)

# %% [markdown]
# ## 3. Utils

# %%
def mse_loss(score, target=1):
    dtype = type(score)
    
    if target == 1:
        label = util.var(torch.ones(score.size()), requires_grad=False)
    elif target == 0:
        label = util.var(torch.zeros(score.size()), requires_grad=False)
    
    criterion = nn.MSELoss().cuda()
    loss = criterion(score, label)
    
    return loss

def L1_loss(pred, target):
    return torch.mean(torch.abs(pred - target))

def lr_decay_rule(epoch, start_decay=100, lr_decay=100):
    decay_rate = 1.0 - (max(0, epoch - start_decay) / float(lr_decay))
    return decay_rate


def save_weight(epoch=None):
    if epoch is None:
        d_cVAE_name = 'D_cVAE.pkl'
        d_cLR_name = 'D_cLR.pkl'
        g_name = 'G.pkl'
        e_name = 'E.pkl'
    else:
        d_cVAE_name = '{epochs}-{name}'.format(epochs=str(epoch), name='D_cVAE.pkl')
        d_cLR_name = '{epochs}-{name}'.format(epochs=str(epoch), name='D_cLR.pkl')
        g_name = '{epochs}-{name}'.format(epochs=str(epoch), name='G.pkl')
        e_name = '{epochs}-{name}'.format(epochs=str(epoch), name='E.pkl')
            
    torch.save(D_cVAE.state_dict(), os.path.join(self.weight_dir, d_cVAE_name))
    torch.save(D_cVAE.state_dict(), os.path.join(self.weight_dir, d_cLR_name))
    torch.save(G.state_dict(), os.path.join(self.weight_dir, g_name))
    torch.save(E.state_dict(), os.path.join(self.weight_dir, e_name))

# %% [markdown]
# ## 4. Load Dataset
# ### 4.1 Preprocessing

# %%
transform = transforms.Compose([
    transforms.Scale((params.img_size, params.img_size)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])

# %% [markdown]
# ### 4.2 DataLoader

# %%
train_dataset = Edges2handbags(params.root, transform=transform, mode='train')
test_dataset = Edges2handbags(params.root, transform=transform, mode='val')

train_data_loader = DataLoader(train_dataset, batch_size=params.batch_size, shuffle=True, num_workers=4, drop_last=True)
test_data_loader = DataLoader(test_dataset, batch_size=params.batch_size, shuffle=True, num_workers=4, drop_last=True)

train_sample = train_dataset.__getitem__(11)
print(train_sample)
print(len(train_sample))
# Out:
# (
# ( 0 ,.,.) =
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#            ...             ⋱             ...
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#
# ( 1 ,.,.) =
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#            ...             ⋱             ...
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#
# ( 2 ,.,.) =
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#            ...             ⋱             ...
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
# [torch.FloatTensor of size 3x128x128]
# ,
# ( 0 ,.,.) =
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#            ...             ⋱             ...
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#
# ( 1 ,.,.) =
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#            ...             ⋱             ...
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#
# ( 2 ,.,.) =
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#            ...             ⋱             ...
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
#   1.0000  1.0000  1.0000  ...   1.0000  1.0000  1.0000
# [torch.FloatTensor of size 3x128x128]
# )
# 2

# %% [markdown]
# ## 5. Build Models & Optimizers & Loss Function

# %% [markdown]
# ### 5.1 Models

# %%
D_cVAE = Discriminator().cuda()
D_cLR = Discriminator().cuda()
G = Generator(z_dim=params.z_dim).cuda()
E = Encoder(z_dim=params.z_dim).cuda()

print(D_cVAE)
print(D_cLR)
print(G)
print(E)
# Out:
# Discriminator(
#   (d_1): Sequential(
#     (0): AvgPool2d(kernel_size=3, stride=2, padding=0, ceil_mode=False, count_include_pad=False)
#     (1): ConvBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): LeakyReLU(0.2, inplace)
#       )
#     )
#     (2): ConvBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (3): ConvBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#         (1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (4): ConvBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(128, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (d_2): Sequential(
#     (0): ConvBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): LeakyReLU(0.2, inplace)
#       )
#     )
#     (1): ConvBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (2): ConvBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (3): ConvBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(256, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
# )
# Discriminator(
#   (d_1): Sequential(
#     (0): AvgPool2d(kernel_size=3, stride=2, padding=0, ceil_mode=False, count_include_pad=False)
#     (1): ConvBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): LeakyReLU(0.2, inplace)
#       )
#     )
#     (2): ConvBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (3): ConvBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#         (1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (4): ConvBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(128, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (d_2): Sequential(
#     (0): ConvBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): LeakyReLU(0.2, inplace)
#       )
#     )
#     (1): ConvBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (2): ConvBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (3): ConvBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(256, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
# )
# Generator(
#   (downsample_1): ConvBlock(
#     (conv_block): Sequential(
#       (0): Conv2d(11, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): LeakyReLU(0.2, inplace)
#     )
#   )
#   (downsample_2): ConvBlock(
#     (conv_block): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       (2): LeakyReLU(0.2, inplace)
#     )
#   )
#   (downsample_3): ConvBlock(
#     (conv_block): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (2): LeakyReLU(0.2, inplace)
#     )
#   )
#   (downsample_4): ConvBlock(
#     (conv_block): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (2): LeakyReLU(0.2, inplace)
#     )
#   )
#   (downsample_5): ConvBlock(
#     (conv_block): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (2): LeakyReLU(0.2, inplace)
#     )
#   )
#   (downsample_6): ConvBlock(
#     (conv_block): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (2): LeakyReLU(0.2, inplace)
#     )
#   )
#   (downsample_7): ConvBlock(
#     (conv_block): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (2): LeakyReLU(0.2, inplace)
#     )
#   )
#   (upsample_1): DeconvBlock(
#     (deconv_block): Sequential(
#       (0): ConvTranspose2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (2): ReLU(inplace)
#     )
#   )
#   (upsample_2): DeconvBlock(
#     (deconv_block): Sequential(
#       (0): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (2): ReLU(inplace)
#     )
#   )
#   (upsample_3): DeconvBlock(
#     (deconv_block): Sequential(
#       (0): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (2): ReLU(inplace)
#     )
#   )
#   (upsample_4): DeconvBlock(
#     (deconv_block): Sequential(
#       (0): ConvTranspose2d(1024, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (2): ReLU(inplace)
#     )
#   )
#   (upsample_5): DeconvBlock(
#     (deconv_block): Sequential(
#       (0): ConvTranspose2d(512, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#       (2): ReLU(inplace)
#     )
#   )
#   (upsample_6): DeconvBlock(
#     (deconv_block): Sequential(
#       (0): ConvTranspose2d(256, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (2): ReLU(inplace)
#     )
#   )
#   (upsample_7): DeconvBlock(
#     (deconv_block): Sequential(
#       (0): ConvTranspose2d(128, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#   )
# )
# Encoder(
#   (conv): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (res_blocks): Sequential(
#     (0): ResBlock(
#       (conv): Sequential(
#         (0): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (1): LeakyReLU(0.2, inplace)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (4): LeakyReLU(0.2, inplace)
#         (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False, count_include_pad=True)
#       )
#       (short_cut): Sequential(
#         (0): AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False, count_include_pad=True)
#         (1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (1): ResBlock(
#       (conv): Sequential(
#         (0): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (1): LeakyReLU(0.2, inplace)
#         (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (4): LeakyReLU(0.2, inplace)
#         (5): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False, count_include_pad=True)
#       )
#       (short_cut): Sequential(
#         (0): AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False, count_include_pad=True)
#         (1): Conv2d(128, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (2): ResBlock(
#       (conv): Sequential(
#         (0): InstanceNorm2d(192, eps=1e-05, momentum=0.1, affine=True)
#         (1): LeakyReLU(0.2, inplace)
#         (2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): InstanceNorm2d(192, eps=1e-05, momentum=0.1, affine=True)
#         (4): LeakyReLU(0.2, inplace)
#         (5): Conv2d(192, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False, count_include_pad=True)
#       )
#       (short_cut): Sequential(
#         (0): AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False, count_include_pad=True)
#         (1): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (pool_block): Sequential(
#     (0): LeakyReLU(0.2, inplace)
#     (1): AvgPool2d(kernel_size=8, stride=8, padding=0, ceil_mode=False, count_include_pad=True)
#   )
#   (fc_mu): Linear(in_features=256, out_features=8, bias=True)
#   (fc_log_var): Linear(in_features=256, out_features=8, bias=True)
# )

# %% [markdown]
# ### 5.2 Optimizers

# %%
optim_D_cVAE = optim.Adam(D_cVAE.parameters(), lr=params.lr, betas=(params.beta_1, params.beta_2))
optim_D_cLR = optim.Adam(D_cLR.parameters(), lr=params.lr, betas=(params.beta_1, params.beta_2))
optim_G = optim.Adam(G.parameters(), lr=params.lr, betas=(params.beta_1, params.beta_2))
optim_E = optim.Adam(E.parameters(), lr=params.lr, betas=(params.beta_1, params.beta_2))

# %%
# 20 x 5 x 8
fixed_z = util.var(torch.randn(params.test_size, params.test_img_num, params.z_dim)).cuda()

# %% [markdown]
# ## 6. Load Pretrained Models

# %%
if params.load_weight is True:
    D_cVAE.load_state_dict(torch.load(os.path.join(params.weight_dir, 'D_cVAE.pkl')))
    D_cLR.load_state_dict(torch.load(os.path.join(params.weight_dir, 'D_cLR.pkl')))
    G.load_state_dict(torch.load(os.path.join(params.weight_dir, 'G.pkl')))
    E.load_state_dict(torch.load(os.path.join(params.weight_dir, 'E.pkl')))

# %%
D_cVAE.train()
D_cLR.train()
G.train()
E.train()
# Out:
# Encoder(
#   (conv): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (res_blocks): Sequential(
#     (0): ResBlock(
#       (conv): Sequential(
#         (0): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (1): LeakyReLU(0.2, inplace)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (4): LeakyReLU(0.2, inplace)
#         (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False, count_include_pad=True)
#       )
#       (short_cut): Sequential(
#         (0): AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False, count_include_pad=True)
#         (1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (1): ResBlock(
#       (conv): Sequential(
#         (0): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (1): LeakyReLU(0.2, inplace)
#         (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#         (4): LeakyReLU(0.2, inplace)
#         (5): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False, count_include_pad=True)
#       )
#       (short_cut): Sequential(
#         (0): AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False, count_include_pad=True)
#         (1): Conv2d(128, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (2): ResBlock(
#       (conv): Sequential(
#         (0): InstanceNorm2d(192, eps=1e-05, momentum=0.1, affine=True)
#         (1): LeakyReLU(0.2, inplace)
#         (2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): InstanceNorm2d(192, eps=1e-05, momentum=0.1, affine=True)
#         (4): LeakyReLU(0.2, inplace)
#         (5): Conv2d(192, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False, count_include_pad=True)
#       )
#       (short_cut): Sequential(
#         (0): AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False, count_include_pad=True)
#         (1): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (pool_block): Sequential(
#     (0): LeakyReLU(0.2, inplace)
#     (1): AvgPool2d(kernel_size=8, stride=8, padding=0, ceil_mode=False, count_include_pad=True)
#   )
#   (fc_mu): Linear(in_features=256, out_features=8, bias=True)
#   (fc_log_var): Linear(in_features=256, out_features=8, bias=True)
# )

# %%
D_A_avg_losses = []
G_GAN_avg_losses = []
KL_div_avg_losses = []
img_recon_avg_losses = []
G_alone_avg_losses = []

for epoch in range(1, params.num_epoch + 1):
    D_A_losses = []
    G_GAN_losses = []
    KL_div_losses = []
    img_recon_losses = []
    G_alone_losses = []
    for iters, (img, ground_truth) in enumerate(train_data_loader): # 1
        # img : (2, 3, 128, 128) of domain A / ground_truth : (2, 3, 128, 128) of domain B
        img, ground_truth = util.var(img), util.var(ground_truth)
        
        # Seperate data for cVAE_GAN and cLR_GAN
        cVAE_data = {'img' : img[0].unsqueeze(dim=0), 'ground_truth' : ground_truth[0].unsqueeze(dim=0)}
        cLR_data = {'img' : img[1].unsqueeze(dim=0), 'ground_truth' : ground_truth[1].unsqueeze(dim=0)}
        
        ''' ----------------------------- 1. Train D ----------------------------- '''
        #############   Step 1. D loss in cVAE-GAN #############
        
        # Encoded latent vector
        mu, log_variance = E(cVAE_data['ground_truth'])
        std = torch.exp(log_variance / 2)
        random_z = util.var(torch.randn(1, params.z_dim))
        encoded_z = (random_z * std) + mu
        
        # Generate fake image
        fake_img_cVAE = G(cVAE_data['img'], encoded_z)
        
        # Get scores and loss
        real_d_cVAE_1, real_d_cVAE_2 = D_cVAE(cVAE_data['ground_truth'])
        fake_d_cVAE_1, fake_d_cVAE_2 = D_cVAE(fake_img_cVAE)
                
        # mse_loss for LSGAN
        D_loss_cVAE_1 = mse_loss(real_d_cVAE_1, 1) + mse_loss(fake_d_cVAE_1, 0)
        D_loss_cVAE_2 = mse_loss(real_d_cVAE_2, 1) + mse_loss(fake_d_cVAE_2, 0)
                
        #############   Step 2. D loss in cLR-GAN   #############

        # Random latent vector
        random_z = util.var(torch.randn(1, params.z_dim))

        # Generate fake image
        fake_img_cLR = G(cLR_data['img'], random_z)

        # Get scores and loss
        real_d_cLR_1, real_d_cLR_2 = D_cLR(cLR_data['ground_truth'])
        fake_d_cLR_1, fake_d_cLR_2 = D_cLR(fake_img_cLR)
        
        D_loss_cLR_1 = mse_loss(real_d_cLR_1, 1) + mse_loss(fake_d_cLR_1, 0)
        D_loss_cLR_2 = mse_loss(real_d_cLR_2, 1) + mse_loss(fake_d_cLR_2, 0)
        
        D_loss = D_loss_cVAE_1 + D_loss_cLR_1 + D_loss_cVAE_2 + D_loss_cLR_2
        
        # Update
        optim_D_cVAE.zero_grad()
        optim_D_cLR.zero_grad()
        optim_G.zero_grad()
        optim_E.zero_grad()
        D_loss.backward()
        optim_D_cVAE.step()
        optim_D_cLR.step()
        
        ''' ----------------------------- 2. Train G & E ----------------------------- '''
        ############# Step 1. GAN loss to fool discriminator (cVAE_GAN and cLR_GAN) #############
        
        # Encoded latent vector
        mu, log_variance = E(cVAE_data['ground_truth'])
        std = torch.exp(log_variance / 2)
        random_z = util.var(torch.randn(1, params.z_dim))
        encoded_z = (random_z * std) + mu
        
        # Generate fake image and get adversarial loss
        fake_img_cVAE = G(cVAE_data['img'], encoded_z)
        fake_d_cVAE_1, fake_d_cVAE_2 = D_cVAE(fake_img_cVAE)
        
        GAN_loss_cVAE_1 = mse_loss(fake_d_cVAE_1, 1)
        GAN_loss_cVAE_2 = mse_loss(fake_d_cVAE_2, 1)
        
        # Random latent vector
        random_z = util.var(torch.randn(1, params.z_dim))
        
        # Generate fake image and get adversarial loss
        fake_img_cLR = G(cLR_data['img'], random_z)
        fake_d_cLR_1, fake_d_cLR_2 = D_cLR(fake_img_cLR)
        
        GAN_loss_cLR_1 = mse_loss(fake_d_cLR_1, 1)
        GAN_loss_cLR_2 = mse_loss(fake_d_cLR_2, 1)
        
        G_GAN_loss = GAN_loss_cVAE_1 + GAN_loss_cVAE_2 + GAN_loss_cLR_1 + GAN_loss_cLR_2
        
        ############# Step 2. KL-divergence with N(0, 1) (cVAE-GAN) #############
                
        KL_div = params.lambda_kl * torch.sum(0.5 * (mu ** 2 + torch.exp(log_variance) - log_variance - 1))
        
        ############# Step 3. Reconstruction of ground truth image (|G(A, z) - B|) (cVAE-GAN) #############
        img_recon_loss = params.lambda_img * L1_loss(fake_img_cVAE, cVAE_data['ground_truth'])
        
        EG_loss = G_GAN_loss + KL_div + img_recon_loss
        optim_D_cVAE.zero_grad()
        optim_D_cLR.zero_grad()
        optim_G.zero_grad()
        optim_E.zero_grad()
        EG_loss.backward(retain_graph=True)
        optim_E.step()
        optim_G.step()
        
        ''' ----------------------------- 3. Train ONLY G ----------------------------- '''
        ############ Step 1. Reconstrution of random latent code (|E(G(A, z)) - z|) (cLR-GAN) ############
                
        # This step should update ONLY G.
        mu_, log_variance_ = E(fake_img_cLR)
        z_recon_loss = L1_loss(mu_, random_z)
        
        G_alone_loss = params.lambda_z * z_recon_loss
        
        optim_D_cVAE.zero_grad()
        optim_D_cLR.zero_grad()
        optim_G.zero_grad()
        optim_E.zero_grad()
        G_alone_loss.backward()
        optim_G.step()
                        
        # Print error and save intermediate result image and weight
        D_A_losses.append(D_loss.data[0])
        G_GAN_losses.append(G_GAN_loss.data[0])
        KL_div_losses.append(KL_div.data[0])
        img_recon_losses.append(img_recon_loss.data[0])
        G_alone_losses.append(G_alone_loss.data[0])
        
        if iters % params.save_every == 0:
            print('[Epoch : %d / Iters : %d/%d] => D_loss : %f / G_GAN_loss : %f / KL_div : %f / img_recon_loss : %f / z_recon_loss : %f'\
                  %(epoch, iters, len(train_data_loader),D_loss.data[0], G_GAN_loss.data[0], KL_div.data[0], img_recon_loss.data[0], G_alone_loss.data[0]))
            
            # Save intermediate result image
            if os.path.exists(params.result_dir) is False:
                os.makedirs(params.result_dir)
                
            result_img = util.make_img(test_data_loader, G, fixed_z, img_num=params.test_img_num, img_size=params.img_size)
                
            img_name = '{epoch}_{iters}.png'.format(epoch=epoch, iters=iters)
            img_path = os.path.join(params.result_dir, img_name)
            
            torchvision.utils.save_image(result_img, img_path, nrow=params.test_img_num+1)
                
            # Save intermediate weight
            if os.path.exists(params.weight_dir) is False:
                os.makedirs(params.weight_dir)
                
            if epoch is None:
                d_cVAE_name = 'D_cVAE.pkl'
                d_cLR_name = 'D_cLR.pkl'
                g_name = 'G.pkl'
                e_name = 'E.pkl'
            else:
                d_cVAE_name = '{epochs}-{name}'.format(epochs=str(epoch), name='D_cVAE.pkl')
                d_cLR_name = '{epochs}-{name}'.format(epochs=str(epoch), name='D_cLR.pkl')
                g_name = '{epochs}-{name}'.format(epochs=str(epoch), name='G.pkl')
                e_name = '{epochs}-{name}'.format(epochs=str(epoch), name='E.pkl')
                
            torch.save(D_cVAE.state_dict(), os.path.join(params.weight_dir, d_cVAE_name))
            torch.save(D_cVAE.state_dict(), os.path.join(params.weight_dir, d_cLR_name))
            torch.save(G.state_dict(), os.path.join(params.weight_dir, g_name))
            torch.save(E.state_dict(), os.path.join(params.weight_dir, e_name))
    
    D_A_avg_loss = torch.mean(torch.FloatTensor(D_A_losses))
    G_GAN_avg_loss = torch.mean(torch.FloatTensor(G_GAN_losses))
    KL_div_avg_loss = torch.mean(torch.FloatTensor(KL_div_losses))
    img_recon_avg_loss = torch.mean(torch.FloatTensor(img_recon_losses))
    G_alone_avg_loss = torch.mean(torch.FloatTensor(G_alone_losses))
    
    D_A_avg_losses.append(D_A_avg_loss)
    G_GAN_avg_losses.append(G_GAN_avg_loss)
    KL_div_avg_losses.append(KL_div_avg_loss)
    img_recon_avg_losses.append(img_recon_avg_loss)
    G_alone_avg_losses.append(G_alone_avg_loss)
    
    # Save weight at the end of every epoch
    if epoch is None:
        d_cVAE_name = 'D_cVAE.pkl'
        d_cLR_name = 'D_cLR.pkl'
        g_name = 'G.pkl'
        e_name = 'E.pkl'
    else:
        d_cVAE_name = '{epochs}-{name}'.format(epochs=str(epoch), name='D_cVAE.pkl')
        d_cLR_name = '{epochs}-{name}'.format(epochs=str(epoch), name='D_cLR.pkl')
        g_name = '{epochs}-{name}'.format(epochs=str(epoch), name='G.pkl')
        e_name = '{epochs}-{name}'.format(epochs=str(epoch), name='E.pkl')
                
    torch.save(D_cVAE.state_dict(), os.path.join(params.weight_dir, d_cVAE_name))
    torch.save(D_cVAE.state_dict(), os.path.join(params.weight_dir, d_cLR_name))
    torch.save(G.state_dict(), os.path.join(params.weight_dir, g_name))
    torch.save(E.state_dict(), os.path.join(params.weight_dir, e_name))
# Out:
# [Epoch : 1 / Iters : 0/24912] => D_loss : 4.603251 / G_GAN_loss : 4.159481 / KL_div : 0.000277 / img_recon_loss : 7.558178 / z_recon_loss : 0.456559
# [Epoch : 1 / Iters : 1000/24912] => D_loss : 1.981351 / G_GAN_loss : 1.223374 / KL_div : 0.047536 / img_recon_loss : 1.530019 / z_recon_loss : 0.390908
# [Epoch : 1 / Iters : 2000/24912] => D_loss : 2.123360 / G_GAN_loss : 1.305619 / KL_div : 0.060278 / img_recon_loss : 1.102830 / z_recon_loss : 0.226525
# [Epoch : 1 / Iters : 3000/24912] => D_loss : 1.948047 / G_GAN_loss : 0.880877 / KL_div : 0.031289 / img_recon_loss : 0.880946 / z_recon_loss : 0.450478
# [Epoch : 1 / Iters : 4000/24912] => D_loss : 2.162253 / G_GAN_loss : 1.074162 / KL_div : 0.057745 / img_recon_loss : 1.648805 / z_recon_loss : 0.275282
# [Epoch : 1 / Iters : 5000/24912] => D_loss : 1.982303 / G_GAN_loss : 1.473475 / KL_div : 0.024556 / img_recon_loss : 1.875346 / z_recon_loss : 0.263723
# [Epoch : 1 / Iters : 6000/24912] => D_loss : 1.724704 / G_GAN_loss : 1.327337 / KL_div : 0.034992 / img_recon_loss : 1.235534 / z_recon_loss : 0.227908
# [Epoch : 1 / Iters : 7000/24912] => D_loss : 1.736137 / G_GAN_loss : 1.164111 / KL_div : 0.031923 / img_recon_loss : 0.659080 / z_recon_loss : 0.360845
# [Epoch : 1 / Iters : 8000/24912] => D_loss : 2.107295 / G_GAN_loss : 1.023924 / KL_div : 0.026400 / img_recon_loss : 1.342075 / z_recon_loss : 0.354126
# [Epoch : 1 / Iters : 9000/24912] => D_loss : 1.684623 / G_GAN_loss : 1.141817 / KL_div : 0.031788 / img_recon_loss : 0.850224 / z_recon_loss : 0.250881
# [Epoch : 1 / Iters : 10000/24912] => D_loss : 1.108289 / G_GAN_loss : 1.357625 / KL_div : 0.080633 / img_recon_loss : 1.218132 / z_recon_loss : 0.449705
# [Epoch : 1 / Iters : 11000/24912] => D_loss : 1.664160 / G_GAN_loss : 1.326823 / KL_div : 0.042142 / img_recon_loss : 1.638057 / z_recon_loss : 0.353350
# [Epoch : 1 / Iters : 12000/24912] => D_loss : 1.830543 / G_GAN_loss : 0.912746 / KL_div : 0.039654 / img_recon_loss : 0.462187 / z_recon_loss : 0.346297
# [Epoch : 1 / Iters : 13000/24912] => D_loss : 2.313124 / G_GAN_loss : 1.540031 / KL_div : 0.055003 / img_recon_loss : 0.738744 / z_recon_loss : 0.303475
# [Epoch : 1 / Iters : 14000/24912] => D_loss : 1.864865 / G_GAN_loss : 1.063913 / KL_div : 0.039479 / img_recon_loss : 0.668465 / z_recon_loss : 0.297736
# [Epoch : 1 / Iters : 15000/24912] => D_loss : 1.691034 / G_GAN_loss : 1.322333 / KL_div : 0.039007 / img_recon_loss : 1.051534 / z_recon_loss : 0.254490
# [Epoch : 1 / Iters : 16000/24912] => D_loss : 1.652696 / G_GAN_loss : 1.542969 / KL_div : 0.032605 / img_recon_loss : 0.906380 / z_recon_loss : 0.356115
# [Epoch : 1 / Iters : 17000/24912] => D_loss : 1.766111 / G_GAN_loss : 0.969452 / KL_div : 0.025958 / img_recon_loss : 1.459373 / z_recon_loss : 0.464468
# [Epoch : 1 / Iters : 18000/24912] => D_loss : 1.660975 / G_GAN_loss : 1.305918 / KL_div : 0.035316 / img_recon_loss : 1.273461 / z_recon_loss : 0.479109
# [Epoch : 1 / Iters : 19000/24912] => D_loss : 1.700339 / G_GAN_loss : 1.150486 / KL_div : 0.085161 / img_recon_loss : 1.759439 / z_recon_loss : 0.326823
# [Epoch : 1 / Iters : 20000/24912] => D_loss : 2.055684 / G_GAN_loss : 1.276729 / KL_div : 0.044888 / img_recon_loss : 0.579978 / z_recon_loss : 0.415188
# [Epoch : 1 / Iters : 21000/24912] => D_loss : 2.374692 / G_GAN_loss : 1.522678 / KL_div : 0.037301 / img_recon_loss : 0.832504 / z_recon_loss : 0.319724
# [Epoch : 1 / Iters : 22000/24912] => D_loss : 2.068500 / G_GAN_loss : 1.316038 / KL_div : 0.038041 / img_recon_loss : 0.888776 / z_recon_loss : 0.402341
# [Epoch : 1 / Iters : 23000/24912] => D_loss : 1.927137 / G_GAN_loss : 1.053044 / KL_div : 0.045651 / img_recon_loss : 0.766380 / z_recon_loss : 0.427071
# [Epoch : 1 / Iters : 24000/24912] => D_loss : 1.566086 / G_GAN_loss : 1.481684 / KL_div : 0.149420 / img_recon_loss : 1.985808 / z_recon_loss : 0.466095
# [Epoch : 2 / Iters : 0/24912] => D_loss : 1.683553 / G_GAN_loss : 1.231765 / KL_div : 0.038163 / img_recon_loss : 1.484017 / z_recon_loss : 0.444830
# [Epoch : 2 / Iters : 1000/24912] => D_loss : 1.909242 / G_GAN_loss : 1.005792 / KL_div : 0.068542 / img_recon_loss : 1.370203 / z_recon_loss : 0.257524
# [Epoch : 2 / Iters : 2000/24912] => D_loss : 1.556453 / G_GAN_loss : 1.178194 / KL_div : 0.035622 / img_recon_loss : 1.750626 / z_recon_loss : 0.413494
# [Epoch : 2 / Iters : 3000/24912] => D_loss : 2.067234 / G_GAN_loss : 1.288867 / KL_div : 0.041393 / img_recon_loss : 1.047479 / z_recon_loss : 0.274468
# [Epoch : 2 / Iters : 4000/24912] => D_loss : 1.748278 / G_GAN_loss : 0.997938 / KL_div : 0.049695 / img_recon_loss : 0.809618 / z_recon_loss : 0.407815
# [Epoch : 2 / Iters : 5000/24912] => D_loss : 1.837756 / G_GAN_loss : 1.449417 / KL_div : 0.060671 / img_recon_loss : 0.762651 / z_recon_loss : 0.128885
# [Epoch : 2 / Iters : 6000/24912] => D_loss : 1.806628 / G_GAN_loss : 1.060340 / KL_div : 0.075706 / img_recon_loss : 0.705452 / z_recon_loss : 0.407015
# [Epoch : 2 / Iters : 7000/24912] => D_loss : 2.023964 / G_GAN_loss : 1.027360 / KL_div : 0.064654 / img_recon_loss : 1.242486 / z_recon_loss : 0.303546
# [Epoch : 2 / Iters : 8000/24912] => D_loss : 2.115547 / G_GAN_loss : 1.229094 / KL_div : 0.076065 / img_recon_loss : 0.770241 / z_recon_loss : 0.163993
# [Epoch : 2 / Iters : 9000/24912] => D_loss : 2.087831 / G_GAN_loss : 1.013965 / KL_div : 0.054844 / img_recon_loss : 2.069683 / z_recon_loss : 0.354299
# [Epoch : 2 / Iters : 10000/24912] => D_loss : 1.677591 / G_GAN_loss : 1.192976 / KL_div : 0.149463 / img_recon_loss : 1.391275 / z_recon_loss : 0.366717
# [Epoch : 2 / Iters : 11000/24912] => D_loss : 1.573323 / G_GAN_loss : 1.043652 / KL_div : 0.062547 / img_recon_loss : 1.117968 / z_recon_loss : 0.264252
# [Epoch : 2 / Iters : 12000/24912] => D_loss : 1.776868 / G_GAN_loss : 1.440140 / KL_div : 0.050485 / img_recon_loss : 0.612624 / z_recon_loss : 0.150363
# [Epoch : 2 / Iters : 13000/24912] => D_loss : 1.714333 / G_GAN_loss : 1.302659 / KL_div : 0.064243 / img_recon_loss : 1.208622 / z_recon_loss : 0.267363
# [Epoch : 2 / Iters : 14000/24912] => D_loss : 1.452040 / G_GAN_loss : 1.258155 / KL_div : 0.053180 / img_recon_loss : 1.360060 / z_recon_loss : 0.245012
# [Epoch : 2 / Iters : 15000/24912] => D_loss : 1.824163 / G_GAN_loss : 1.302809 / KL_div : 0.074250 / img_recon_loss : 0.721031 / z_recon_loss : 0.332105
# [Epoch : 2 / Iters : 16000/24912] => D_loss : 1.738036 / G_GAN_loss : 1.044437 / KL_div : 0.048173 / img_recon_loss : 1.099700 / z_recon_loss : 0.326691
# [Epoch : 2 / Iters : 17000/24912] => D_loss : 3.049651 / G_GAN_loss : 1.252450 / KL_div : 0.090162 / img_recon_loss : 1.142380 / z_recon_loss : 0.273062
# [Epoch : 2 / Iters : 18000/24912] => D_loss : 2.050075 / G_GAN_loss : 1.015125 / KL_div : 0.063754 / img_recon_loss : 1.859816 / z_recon_loss : 0.416556
# [Epoch : 2 / Iters : 19000/24912] => D_loss : 1.679338 / G_GAN_loss : 1.256391 / KL_div : 0.045011 / img_recon_loss : 0.488640 / z_recon_loss : 0.273109
# [Epoch : 2 / Iters : 20000/24912] => D_loss : 1.650971 / G_GAN_loss : 1.248460 / KL_div : 0.039984 / img_recon_loss : 1.201507 / z_recon_loss : 0.137352
# [Epoch : 2 / Iters : 21000/24912] => D_loss : 1.994887 / G_GAN_loss : 1.398149 / KL_div : 0.065684 / img_recon_loss : 0.841473 / z_recon_loss : 0.422631
# [Epoch : 2 / Iters : 22000/24912] => D_loss : 1.981156 / G_GAN_loss : 1.195870 / KL_div : 0.055113 / img_recon_loss : 0.678834 / z_recon_loss : 0.407464
# [Epoch : 2 / Iters : 23000/24912] => D_loss : 1.865720 / G_GAN_loss : 1.396013 / KL_div : 0.062780 / img_recon_loss : 0.971236 / z_recon_loss : 0.328343
# [Epoch : 2 / Iters : 24000/24912] => D_loss : 1.863102 / G_GAN_loss : 0.762764 / KL_div : 0.048604 / img_recon_loss : 0.864675 / z_recon_loss : 0.314343
# [Epoch : 3 / Iters : 0/24912] => D_loss : 1.856324 / G_GAN_loss : 1.127166 / KL_div : 0.055647 / img_recon_loss : 0.769919 / z_recon_loss : 0.161853
# [Epoch : 3 / Iters : 1000/24912] => D_loss : 1.961435 / G_GAN_loss : 0.830006 / KL_div : 0.049541 / img_recon_loss : 0.627938 / z_recon_loss : 0.471197
# [Epoch : 3 / Iters : 2000/24912] => D_loss : 2.003216 / G_GAN_loss : 1.211705 / KL_div : 0.058059 / img_recon_loss : 0.721772 / z_recon_loss : 0.205256
# [Epoch : 3 / Iters : 3000/24912] => D_loss : 2.216106 / G_GAN_loss : 1.052141 / KL_div : 0.054107 / img_recon_loss : 0.500365 / z_recon_loss : 0.330983
# [Epoch : 3 / Iters : 4000/24912] => D_loss : 1.841560 / G_GAN_loss : 1.297620 / KL_div : 0.065383 / img_recon_loss : 1.234728 / z_recon_loss : 0.459872
# [Epoch : 3 / Iters : 5000/24912] => D_loss : 2.145462 / G_GAN_loss : 1.042770 / KL_div : 0.042922 / img_recon_loss : 0.833302 / z_recon_loss : 0.300104
# [Epoch : 3 / Iters : 6000/24912] => D_loss : 1.687431 / G_GAN_loss : 1.360591 / KL_div : 0.091470 / img_recon_loss : 1.264833 / z_recon_loss : 0.267407
# [Epoch : 3 / Iters : 7000/24912] => D_loss : 2.063912 / G_GAN_loss : 1.225348 / KL_div : 0.066107 / img_recon_loss : 1.143244 / z_recon_loss : 0.177391
# [Epoch : 3 / Iters : 8000/24912] => D_loss : 2.292648 / G_GAN_loss : 0.851084 / KL_div : 0.063794 / img_recon_loss : 0.670752 / z_recon_loss : 0.406215
# [Epoch : 3 / Iters : 9000/24912] => D_loss : 1.717583 / G_GAN_loss : 1.293704 / KL_div : 0.075155 / img_recon_loss : 1.278809 / z_recon_loss : 0.276675
# [Epoch : 3 / Iters : 10000/24912] => D_loss : 1.803439 / G_GAN_loss : 1.289641 / KL_div : 0.064389 / img_recon_loss : 0.843017 / z_recon_loss : 0.475273
# [Epoch : 3 / Iters : 11000/24912] => D_loss : 2.038804 / G_GAN_loss : 1.101885 / KL_div : 0.087773 / img_recon_loss : 1.191127 / z_recon_loss : 0.363923
# [Epoch : 3 / Iters : 12000/24912] => D_loss : 1.863715 / G_GAN_loss : 1.007791 / KL_div : 0.075830 / img_recon_loss : 1.387689 / z_recon_loss : 0.435954
# [Epoch : 3 / Iters : 13000/24912] => D_loss : 1.774335 / G_GAN_loss : 1.229270 / KL_div : 0.046980 / img_recon_loss : 0.838868 / z_recon_loss : 0.209175
# [Epoch : 3 / Iters : 14000/24912] => D_loss : 1.823967 / G_GAN_loss : 1.925027 / KL_div : 0.053438 / img_recon_loss : 1.165283 / z_recon_loss : 0.340109
# [Epoch : 3 / Iters : 15000/24912] => D_loss : 2.193456 / G_GAN_loss : 1.116331 / KL_div : 0.056674 / img_recon_loss : 1.169991 / z_recon_loss : 0.305887
# [Epoch : 3 / Iters : 16000/24912] => D_loss : 2.095491 / G_GAN_loss : 1.055240 / KL_div : 0.055088 / img_recon_loss : 0.559768 / z_recon_loss : 0.276626
# [Epoch : 3 / Iters : 17000/24912] => D_loss : 1.852871 / G_GAN_loss : 1.110337 / KL_div : 0.055382 / img_recon_loss : 0.580073 / z_recon_loss : 0.269547
# [Epoch : 3 / Iters : 18000/24912] => D_loss : 2.358719 / G_GAN_loss : 1.298131 / KL_div : 0.055956 / img_recon_loss : 1.052593 / z_recon_loss : 0.300562
# [Epoch : 3 / Iters : 19000/24912] => D_loss : 2.192567 / G_GAN_loss : 1.013585 / KL_div : 0.048351 / img_recon_loss : 0.575758 / z_recon_loss : 0.326231
# [Epoch : 3 / Iters : 20000/24912] => D_loss : 2.248532 / G_GAN_loss : 0.995042 / KL_div : 0.062706 / img_recon_loss : 0.607968 / z_recon_loss : 0.314424
# [Epoch : 3 / Iters : 21000/24912] => D_loss : 1.969642 / G_GAN_loss : 1.220297 / KL_div : 0.055167 / img_recon_loss : 0.605706 / z_recon_loss : 0.228788
# [Epoch : 3 / Iters : 22000/24912] => D_loss : 1.521040 / G_GAN_loss : 1.093648 / KL_div : 0.061399 / img_recon_loss : 1.405039 / z_recon_loss : 0.205792
# [Epoch : 3 / Iters : 23000/24912] => D_loss : 1.501860 / G_GAN_loss : 0.863429 / KL_div : 0.057250 / img_recon_loss : 0.832599 / z_recon_loss : 0.566049
# [Epoch : 3 / Iters : 24000/24912] => D_loss : 1.791883 / G_GAN_loss : 1.149374 / KL_div : 0.080712 / img_recon_loss : 1.055299 / z_recon_loss : 0.495880
# [Epoch : 4 / Iters : 0/24912] => D_loss : 2.330848 / G_GAN_loss : 1.285400 / KL_div : 0.059738 / img_recon_loss : 0.722039 / z_recon_loss : 0.295477
# [Epoch : 4 / Iters : 1000/24912] => D_loss : 1.989204 / G_GAN_loss : 1.313666 / KL_div : 0.079196 / img_recon_loss : 0.794503 / z_recon_loss : 0.418803
# [Epoch : 4 / Iters : 2000/24912] => D_loss : 1.816745 / G_GAN_loss : 1.144899 / KL_div : 0.075150 / img_recon_loss : 0.688758 / z_recon_loss : 0.308790
# [Epoch : 4 / Iters : 3000/24912] => D_loss : 1.833621 / G_GAN_loss : 1.080821 / KL_div : 0.047735 / img_recon_loss : 0.314406 / z_recon_loss : 0.340468
# [Epoch : 4 / Iters : 4000/24912] => D_loss : 2.032542 / G_GAN_loss : 1.079390 / KL_div : 0.051956 / img_recon_loss : 0.553275 / z_recon_loss : 0.211196
# [Epoch : 4 / Iters : 5000/24912] => D_loss : 1.834935 / G_GAN_loss : 1.182528 / KL_div : 0.060681 / img_recon_loss : 1.874529 / z_recon_loss : 0.383819
# [Epoch : 4 / Iters : 6000/24912] => D_loss : 1.762853 / G_GAN_loss : 1.059543 / KL_div : 0.033030 / img_recon_loss : 0.382206 / z_recon_loss : 0.197630
# [Epoch : 4 / Iters : 7000/24912] => D_loss : 2.072126 / G_GAN_loss : 0.979179 / KL_div : 0.082058 / img_recon_loss : 1.422086 / z_recon_loss : 0.205833
# [Epoch : 4 / Iters : 8000/24912] => D_loss : 1.980694 / G_GAN_loss : 1.220131 / KL_div : 0.133642 / img_recon_loss : 0.930716 / z_recon_loss : 0.307286
# [Epoch : 4 / Iters : 9000/24912] => D_loss : 2.047931 / G_GAN_loss : 1.151178 / KL_div : 0.050014 / img_recon_loss : 0.411535 / z_recon_loss : 0.385678
# [Epoch : 4 / Iters : 10000/24912] => D_loss : 2.039410 / G_GAN_loss : 1.133990 / KL_div : 0.071915 / img_recon_loss : 0.734611 / z_recon_loss : 0.271684
# [Epoch : 4 / Iters : 11000/24912] => D_loss : 1.623981 / G_GAN_loss : 1.376197 / KL_div : 0.080163 / img_recon_loss : 1.652629 / z_recon_loss : 0.204647
# [Epoch : 4 / Iters : 12000/24912] => D_loss : 1.660610 / G_GAN_loss : 1.115678 / KL_div : 0.058576 / img_recon_loss : 1.551391 / z_recon_loss : 0.298709
# [Epoch : 4 / Iters : 13000/24912] => D_loss : 1.928712 / G_GAN_loss : 0.997794 / KL_div : 0.053357 / img_recon_loss : 0.699191 / z_recon_loss : 0.308984
# [Epoch : 4 / Iters : 14000/24912] => D_loss : 1.808604 / G_GAN_loss : 0.921599 / KL_div : 0.051919 / img_recon_loss : 0.510244 / z_recon_loss : 0.251896
# [Epoch : 4 / Iters : 15000/24912] => D_loss : 1.807076 / G_GAN_loss : 1.050228 / KL_div : 0.072393 / img_recon_loss : 0.627236 / z_recon_loss : 0.235585
# [Epoch : 4 / Iters : 16000/24912] => D_loss : 1.984953 / G_GAN_loss : 1.179674 / KL_div : 0.073607 / img_recon_loss : 1.270917 / z_recon_loss : 0.459716
# [Epoch : 4 / Iters : 17000/24912] => D_loss : 1.595898 / G_GAN_loss : 1.359230 / KL_div : 0.074001 / img_recon_loss : 0.832936 / z_recon_loss : 0.260660
# [Epoch : 4 / Iters : 18000/24912] => D_loss : 1.781002 / G_GAN_loss : 0.933287 / KL_div : 0.063971 / img_recon_loss : 1.783165 / z_recon_loss : 0.165432
# [Epoch : 4 / Iters : 19000/24912] => D_loss : 2.108648 / G_GAN_loss : 1.355966 / KL_div : 0.064868 / img_recon_loss : 0.663791 / z_recon_loss : 0.291638
# [Epoch : 4 / Iters : 20000/24912] => D_loss : 1.884366 / G_GAN_loss : 1.101930 / KL_div : 0.064290 / img_recon_loss : 1.167221 / z_recon_loss : 0.421179
# [Epoch : 4 / Iters : 21000/24912] => D_loss : 1.814964 / G_GAN_loss : 1.323353 / KL_div : 0.083437 / img_recon_loss : 1.139689 / z_recon_loss : 0.290160
# [Epoch : 4 / Iters : 22000/24912] => D_loss : 1.978499 / G_GAN_loss : 0.886506 / KL_div : 0.073318 / img_recon_loss : 0.551999 / z_recon_loss : 0.200234
# [Epoch : 4 / Iters : 23000/24912] => D_loss : 1.820772 / G_GAN_loss : 1.165447 / KL_div : 0.063136 / img_recon_loss : 0.515479 / z_recon_loss : 0.450380
# [Epoch : 4 / Iters : 24000/24912] => D_loss : 1.925053 / G_GAN_loss : 1.242959 / KL_div : 0.072997 / img_recon_loss : 0.837634 / z_recon_loss : 0.155594
# [Epoch : 5 / Iters : 0/24912] => D_loss : 1.894681 / G_GAN_loss : 1.055827 / KL_div : 0.057391 / img_recon_loss : 1.590855 / z_recon_loss : 0.262741
# [Epoch : 5 / Iters : 1000/24912] => D_loss : 1.851508 / G_GAN_loss : 0.980297 / KL_div : 0.147782 / img_recon_loss : 1.500117 / z_recon_loss : 0.340488
# [Epoch : 5 / Iters : 2000/24912] => D_loss : 1.806429 / G_GAN_loss : 1.266937 / KL_div : 0.058707 / img_recon_loss : 0.619458 / z_recon_loss : 0.259618
# [Epoch : 5 / Iters : 3000/24912] => D_loss : 1.662482 / G_GAN_loss : 1.106292 / KL_div : 0.056322 / img_recon_loss : 2.892660 / z_recon_loss : 0.190156
# [Epoch : 5 / Iters : 4000/24912] => D_loss : 1.791315 / G_GAN_loss : 1.174003 / KL_div : 0.061297 / img_recon_loss : 0.908959 / z_recon_loss : 0.443904
# [Epoch : 5 / Iters : 5000/24912] => D_loss : 1.932144 / G_GAN_loss : 1.202216 / KL_div : 0.053947 / img_recon_loss : 0.962139 / z_recon_loss : 0.300978
# [Epoch : 5 / Iters : 6000/24912] => D_loss : 2.156031 / G_GAN_loss : 1.069910 / KL_div : 0.049210 / img_recon_loss : 0.431813 / z_recon_loss : 0.228398
# [Epoch : 5 / Iters : 7000/24912] => D_loss : 1.913113 / G_GAN_loss : 0.938668 / KL_div : 0.060031 / img_recon_loss : 0.946726 / z_recon_loss : 0.281332
# [Epoch : 5 / Iters : 8000/24912] => D_loss : 2.112868 / G_GAN_loss : 0.823576 / KL_div : 0.085143 / img_recon_loss : 1.144694 / z_recon_loss : 0.508547
# [Epoch : 5 / Iters : 9000/24912] => D_loss : 1.897226 / G_GAN_loss : 1.095377 / KL_div : 0.088128 / img_recon_loss : 0.597625 / z_recon_loss : 0.254169
# [Epoch : 5 / Iters : 10000/24912] => D_loss : 1.531724 / G_GAN_loss : 1.110777 / KL_div : 0.076599 / img_recon_loss : 1.515151 / z_recon_loss : 0.380637
# [Epoch : 5 / Iters : 11000/24912] => D_loss : 1.946244 / G_GAN_loss : 0.989890 / KL_div : 0.120858 / img_recon_loss : 0.729216 / z_recon_loss : 0.333066
# [Epoch : 5 / Iters : 12000/24912] => D_loss : 2.033694 / G_GAN_loss : 1.194821 / KL_div : 0.090540 / img_recon_loss : 0.654018 / z_recon_loss : 0.310838
# [Epoch : 5 / Iters : 13000/24912] => D_loss : 1.802564 / G_GAN_loss : 1.073138 / KL_div : 0.082131 / img_recon_loss : 0.930791 / z_recon_loss : 0.274080
# [Epoch : 5 / Iters : 14000/24912] => D_loss : 2.238050 / G_GAN_loss : 1.080336 / KL_div : 0.069889 / img_recon_loss : 0.646139 / z_recon_loss : 0.278528
# [Epoch : 5 / Iters : 15000/24912] => D_loss : 1.841210 / G_GAN_loss : 0.950408 / KL_div : 0.088732 / img_recon_loss : 0.684677 / z_recon_loss : 0.222309
# [Epoch : 5 / Iters : 16000/24912] => D_loss : 1.892935 / G_GAN_loss : 1.274094 / KL_div : 0.058123 / img_recon_loss : 0.537020 / z_recon_loss : 0.402474
# [Epoch : 5 / Iters : 17000/24912] => D_loss : 2.145386 / G_GAN_loss : 1.133998 / KL_div : 0.076779 / img_recon_loss : 0.538343 / z_recon_loss : 0.454376
# [Epoch : 5 / Iters : 18000/24912] => D_loss : 1.981180 / G_GAN_loss : 1.195107 / KL_div : 0.061752 / img_recon_loss : 0.779857 / z_recon_loss : 0.341611
# [Epoch : 5 / Iters : 19000/24912] => D_loss : 2.089478 / G_GAN_loss : 1.214167 / KL_div : 0.065478 / img_recon_loss : 0.736737 / z_recon_loss : 0.222913
# [Epoch : 5 / Iters : 20000/24912] => D_loss : 2.201381 / G_GAN_loss : 1.298322 / KL_div : 0.092161 / img_recon_loss : 0.738087 / z_recon_loss : 0.284722
# [Epoch : 5 / Iters : 21000/24912] => D_loss : 1.722933 / G_GAN_loss : 0.899654 / KL_div : 0.057856 / img_recon_loss : 0.595234 / z_recon_loss : 0.330628
# [Epoch : 5 / Iters : 22000/24912] => D_loss : 2.038573 / G_GAN_loss : 0.920075 / KL_div : 0.051520 / img_recon_loss : 0.355201 / z_recon_loss : 0.282457
# [Epoch : 5 / Iters : 23000/24912] => D_loss : 2.043256 / G_GAN_loss : 1.323282 / KL_div : 0.085431 / img_recon_loss : 1.032145 / z_recon_loss : 0.265870
# [Epoch : 5 / Iters : 24000/24912] => D_loss : 1.662290 / G_GAN_loss : 1.113095 / KL_div : 0.061542 / img_recon_loss : 1.063369 / z_recon_loss : 0.177410
# [Epoch : 6 / Iters : 0/24912] => D_loss : 1.833163 / G_GAN_loss : 1.090037 / KL_div : 0.048620 / img_recon_loss : 0.393367 / z_recon_loss : 0.349964
# [Epoch : 6 / Iters : 1000/24912] => D_loss : 1.914736 / G_GAN_loss : 1.040104 / KL_div : 0.081495 / img_recon_loss : 0.752217 / z_recon_loss : 0.225629
# [Epoch : 6 / Iters : 2000/24912] => D_loss : 1.701480 / G_GAN_loss : 1.105876 / KL_div : 0.064923 / img_recon_loss : 1.321593 / z_recon_loss : 0.239466
# [Epoch : 6 / Iters : 3000/24912] => D_loss : 1.758929 / G_GAN_loss : 1.485901 / KL_div : 0.081154 / img_recon_loss : 0.616943 / z_recon_loss : 0.293448
# [Epoch : 6 / Iters : 4000/24912] => D_loss : 1.958136 / G_GAN_loss : 1.180339 / KL_div : 0.075047 / img_recon_loss : 0.554343 / z_recon_loss : 0.312515
# [Epoch : 6 / Iters : 5000/24912] => D_loss : 1.979427 / G_GAN_loss : 0.865685 / KL_div : 0.099227 / img_recon_loss : 0.845320 / z_recon_loss : 0.423825
# [Epoch : 6 / Iters : 6000/24912] => D_loss : 1.757456 / G_GAN_loss : 1.159598 / KL_div : 0.071636 / img_recon_loss : 1.103096 / z_recon_loss : 0.354958
# [Epoch : 6 / Iters : 7000/24912] => D_loss : 2.240784 / G_GAN_loss : 0.828561 / KL_div : 0.064759 / img_recon_loss : 0.997697 / z_recon_loss : 0.207658
# [Epoch : 6 / Iters : 8000/24912] => D_loss : 2.123291 / G_GAN_loss : 1.322777 / KL_div : 0.088865 / img_recon_loss : 1.206394 / z_recon_loss : 0.164440
# [Epoch : 6 / Iters : 9000/24912] => D_loss : 2.223678 / G_GAN_loss : 1.467462 / KL_div : 0.065992 / img_recon_loss : 0.472797 / z_recon_loss : 0.252954
# [Epoch : 6 / Iters : 10000/24912] => D_loss : 2.043389 / G_GAN_loss : 1.073439 / KL_div : 0.088602 / img_recon_loss : 1.515479 / z_recon_loss : 0.173089
# [Epoch : 6 / Iters : 11000/24912] => D_loss : 2.093079 / G_GAN_loss : 1.184388 / KL_div : 0.102003 / img_recon_loss : 0.352380 / z_recon_loss : 0.192659
# [Epoch : 6 / Iters : 12000/24912] => D_loss : 1.794577 / G_GAN_loss : 1.261253 / KL_div : 0.066024 / img_recon_loss : 1.333662 / z_recon_loss : 0.340243
# [Epoch : 6 / Iters : 13000/24912] => D_loss : 1.938892 / G_GAN_loss : 1.146293 / KL_div : 0.047779 / img_recon_loss : 0.858629 / z_recon_loss : 0.203775
# [Epoch : 6 / Iters : 14000/24912] => D_loss : 2.083539 / G_GAN_loss : 1.114130 / KL_div : 0.057280 / img_recon_loss : 0.478491 / z_recon_loss : 0.427772
# [Epoch : 6 / Iters : 15000/24912] => D_loss : 1.766997 / G_GAN_loss : 1.420404 / KL_div : 0.067547 / img_recon_loss : 2.393038 / z_recon_loss : 0.177013
# [Epoch : 6 / Iters : 16000/24912] => D_loss : 1.694151 / G_GAN_loss : 1.242395 / KL_div : 0.074829 / img_recon_loss : 1.773299 / z_recon_loss : 0.291354
# [Epoch : 6 / Iters : 17000/24912] => D_loss : 1.928210 / G_GAN_loss : 1.149383 / KL_div : 0.067977 / img_recon_loss : 0.689286 / z_recon_loss : 0.269266
# [Epoch : 6 / Iters : 18000/24912] => D_loss : 1.450207 / G_GAN_loss : 1.392675 / KL_div : 0.092154 / img_recon_loss : 1.016421 / z_recon_loss : 0.501336
# [Epoch : 6 / Iters : 19000/24912] => D_loss : 1.536208 / G_GAN_loss : 1.654117 / KL_div : 0.064059 / img_recon_loss : 0.777949 / z_recon_loss : 0.213269
# [Epoch : 6 / Iters : 20000/24912] => D_loss : 1.679034 / G_GAN_loss : 1.358559 / KL_div : 0.079559 / img_recon_loss : 1.616604 / z_recon_loss : 0.272478
# [Epoch : 6 / Iters : 21000/24912] => D_loss : 1.717459 / G_GAN_loss : 1.287950 / KL_div : 0.063862 / img_recon_loss : 0.790779 / z_recon_loss : 0.269044
# [Epoch : 6 / Iters : 22000/24912] => D_loss : 1.591321 / G_GAN_loss : 1.341042 / KL_div : 0.092871 / img_recon_loss : 0.919472 / z_recon_loss : 0.271837
# [Epoch : 6 / Iters : 23000/24912] => D_loss : 1.832271 / G_GAN_loss : 0.963950 / KL_div : 0.047191 / img_recon_loss : 0.817960 / z_recon_loss : 0.405116
# [Epoch : 6 / Iters : 24000/24912] => D_loss : 1.978148 / G_GAN_loss : 1.094433 / KL_div : 0.109367 / img_recon_loss : 0.650578 / z_recon_loss : 0.411493
# [Epoch : 7 / Iters : 0/24912] => D_loss : 1.405238 / G_GAN_loss : 1.342413 / KL_div : 0.089321 / img_recon_loss : 1.384325 / z_recon_loss : 0.259995
# [Epoch : 7 / Iters : 1000/24912] => D_loss : 2.077214 / G_GAN_loss : 1.068645 / KL_div : 0.058908 / img_recon_loss : 0.578123 / z_recon_loss : 0.297767
# [Epoch : 7 / Iters : 2000/24912] => D_loss : 1.655036 / G_GAN_loss : 1.524492 / KL_div : 0.079641 / img_recon_loss : 0.578027 / z_recon_loss : 0.416649
# [Epoch : 7 / Iters : 3000/24912] => D_loss : 1.939914 / G_GAN_loss : 1.509198 / KL_div : 0.063104 / img_recon_loss : 0.922074 / z_recon_loss : 0.117483
# [Epoch : 7 / Iters : 4000/24912] => D_loss : 2.255316 / G_GAN_loss : 0.975408 / KL_div : 0.057382 / img_recon_loss : 0.587621 / z_recon_loss : 0.301880
# [Epoch : 7 / Iters : 5000/24912] => D_loss : 2.236588 / G_GAN_loss : 0.926230 / KL_div : 0.063964 / img_recon_loss : 0.744761 / z_recon_loss : 0.260774
# [Epoch : 7 / Iters : 6000/24912] => D_loss : 1.892915 / G_GAN_loss : 1.136189 / KL_div : 0.086295 / img_recon_loss : 1.114170 / z_recon_loss : 0.387227
# [Epoch : 7 / Iters : 7000/24912] => D_loss : 1.908084 / G_GAN_loss : 1.103824 / KL_div : 0.068036 / img_recon_loss : 1.211711 / z_recon_loss : 0.303993
# [Epoch : 7 / Iters : 8000/24912] => D_loss : 2.057547 / G_GAN_loss : 1.085912 / KL_div : 0.050655 / img_recon_loss : 0.284953 / z_recon_loss : 0.327627
# [Epoch : 7 / Iters : 9000/24912] => D_loss : 1.883903 / G_GAN_loss : 0.997731 / KL_div : 0.116392 / img_recon_loss : 1.279799 / z_recon_loss : 0.176670
# [Epoch : 7 / Iters : 10000/24912] => D_loss : 1.791566 / G_GAN_loss : 0.979940 / KL_div : 0.067919 / img_recon_loss : 0.475368 / z_recon_loss : 0.294833
# [Epoch : 7 / Iters : 11000/24912] => D_loss : 2.146665 / G_GAN_loss : 1.153430 / KL_div : 0.062811 / img_recon_loss : 0.684942 / z_recon_loss : 0.310102
# [Epoch : 7 / Iters : 12000/24912] => D_loss : 1.832914 / G_GAN_loss : 0.911621 / KL_div : 0.099744 / img_recon_loss : 1.172057 / z_recon_loss : 0.376637
# [Epoch : 7 / Iters : 13000/24912] => D_loss : 1.471245 / G_GAN_loss : 1.221214 / KL_div : 0.075535 / img_recon_loss : 1.033417 / z_recon_loss : 0.378407
# [Epoch : 7 / Iters : 14000/24912] => D_loss : 2.113875 / G_GAN_loss : 1.109149 / KL_div : 0.066619 / img_recon_loss : 0.626220 / z_recon_loss : 0.297430
# [Epoch : 7 / Iters : 15000/24912] => D_loss : 1.872684 / G_GAN_loss : 0.855463 / KL_div : 0.066350 / img_recon_loss : 0.701629 / z_recon_loss : 0.276716
# [Epoch : 7 / Iters : 16000/24912] => D_loss : 2.105702 / G_GAN_loss : 1.065383 / KL_div : 0.063630 / img_recon_loss : 0.469000 / z_recon_loss : 0.502947
# [Epoch : 7 / Iters : 17000/24912] => D_loss : 1.456427 / G_GAN_loss : 1.411275 / KL_div : 0.089081 / img_recon_loss : 2.564306 / z_recon_loss : 0.273868
# [Epoch : 7 / Iters : 18000/24912] => D_loss : 1.786429 / G_GAN_loss : 1.030976 / KL_div : 0.063221 / img_recon_loss : 0.779628 / z_recon_loss : 0.103766
# [Epoch : 7 / Iters : 19000/24912] => D_loss : 1.906516 / G_GAN_loss : 1.119644 / KL_div : 0.058324 / img_recon_loss : 0.525577 / z_recon_loss : 0.336459
# [Epoch : 7 / Iters : 20000/24912] => D_loss : 1.945687 / G_GAN_loss : 1.066753 / KL_div : 0.066189 / img_recon_loss : 0.741057 / z_recon_loss : 0.244515
# [Epoch : 7 / Iters : 21000/24912] => D_loss : 1.856377 / G_GAN_loss : 1.089280 / KL_div : 0.061209 / img_recon_loss : 0.579831 / z_recon_loss : 0.357752
# [Epoch : 7 / Iters : 22000/24912] => D_loss : 2.016917 / G_GAN_loss : 1.163498 / KL_div : 0.138088 / img_recon_loss : 1.565710 / z_recon_loss : 0.288141
# [Epoch : 7 / Iters : 23000/24912] => D_loss : 1.997415 / G_GAN_loss : 1.094550 / KL_div : 0.102345 / img_recon_loss : 1.069809 / z_recon_loss : 0.540100
# [Epoch : 7 / Iters : 24000/24912] => D_loss : 2.081410 / G_GAN_loss : 1.462213 / KL_div : 0.092605 / img_recon_loss : 0.887067 / z_recon_loss : 0.438854
# [Epoch : 8 / Iters : 0/24912] => D_loss : 1.900586 / G_GAN_loss : 1.158749 / KL_div : 0.084564 / img_recon_loss : 1.077258 / z_recon_loss : 0.285308
# [Epoch : 8 / Iters : 1000/24912] => D_loss : 1.634762 / G_GAN_loss : 1.236887 / KL_div : 0.088730 / img_recon_loss : 1.489523 / z_recon_loss : 0.285807
# [Epoch : 8 / Iters : 2000/24912] => D_loss : 1.651003 / G_GAN_loss : 1.363797 / KL_div : 0.088168 / img_recon_loss : 1.114118 / z_recon_loss : 0.119153
# [Epoch : 8 / Iters : 3000/24912] => D_loss : 1.793181 / G_GAN_loss : 1.217129 / KL_div : 0.082753 / img_recon_loss : 1.406043 / z_recon_loss : 0.304963
# [Epoch : 8 / Iters : 4000/24912] => D_loss : 1.754647 / G_GAN_loss : 1.268815 / KL_div : 0.077189 / img_recon_loss : 0.599872 / z_recon_loss : 0.259416
# [Epoch : 8 / Iters : 5000/24912] => D_loss : 1.761900 / G_GAN_loss : 1.139587 / KL_div : 0.065148 / img_recon_loss : 0.728648 / z_recon_loss : 0.418780
# [Epoch : 8 / Iters : 6000/24912] => D_loss : 1.941679 / G_GAN_loss : 1.268728 / KL_div : 0.131913 / img_recon_loss : 1.329417 / z_recon_loss : 0.241838
# [Epoch : 8 / Iters : 7000/24912] => D_loss : 1.392469 / G_GAN_loss : 1.675050 / KL_div : 0.136498 / img_recon_loss : 1.673080 / z_recon_loss : 0.380819
# [Epoch : 8 / Iters : 8000/24912] => D_loss : 1.869450 / G_GAN_loss : 1.368709 / KL_div : 0.105844 / img_recon_loss : 1.472390 / z_recon_loss : 0.389460
# [Epoch : 8 / Iters : 9000/24912] => D_loss : 1.892142 / G_GAN_loss : 1.460289 / KL_div : 0.070157 / img_recon_loss : 0.701055 / z_recon_loss : 0.314116
# [Epoch : 8 / Iters : 10000/24912] => D_loss : 1.700791 / G_GAN_loss : 1.258784 / KL_div : 0.077915 / img_recon_loss : 0.558385 / z_recon_loss : 0.322643
# [Epoch : 8 / Iters : 11000/24912] => D_loss : 2.006634 / G_GAN_loss : 1.078772 / KL_div : 0.067490 / img_recon_loss : 0.707426 / z_recon_loss : 0.116377
# [Epoch : 8 / Iters : 12000/24912] => D_loss : 1.913483 / G_GAN_loss : 1.022363 / KL_div : 0.062341 / img_recon_loss : 0.519927 / z_recon_loss : 0.167848
# [Epoch : 8 / Iters : 13000/24912] => D_loss : 1.884473 / G_GAN_loss : 1.327116 / KL_div : 0.103044 / img_recon_loss : 0.952497 / z_recon_loss : 0.285807
# [Epoch : 8 / Iters : 14000/24912] => D_loss : 1.909133 / G_GAN_loss : 1.100138 / KL_div : 0.075456 / img_recon_loss : 0.722011 / z_recon_loss : 0.384606
# [Epoch : 8 / Iters : 15000/24912] => D_loss : 1.722287 / G_GAN_loss : 0.867091 / KL_div : 0.076374 / img_recon_loss : 1.159765 / z_recon_loss : 0.405742
# [Epoch : 8 / Iters : 16000/24912] => D_loss : 1.624302 / G_GAN_loss : 0.980807 / KL_div : 0.062972 / img_recon_loss : 1.256956 / z_recon_loss : 0.201812
# [Epoch : 8 / Iters : 17000/24912] => D_loss : 1.892038 / G_GAN_loss : 1.044049 / KL_div : 0.055240 / img_recon_loss : 0.352985 / z_recon_loss : 0.474932
# [Epoch : 8 / Iters : 18000/24912] => D_loss : 2.016268 / G_GAN_loss : 1.021778 / KL_div : 0.112551 / img_recon_loss : 0.696671 / z_recon_loss : 0.221878
# [Epoch : 8 / Iters : 19000/24912] => D_loss : 1.900280 / G_GAN_loss : 1.020311 / KL_div : 0.062929 / img_recon_loss : 0.555720 / z_recon_loss : 0.282589
# [Epoch : 8 / Iters : 20000/24912] => D_loss : 2.129268 / G_GAN_loss : 1.198375 / KL_div : 0.071840 / img_recon_loss : 0.481592 / z_recon_loss : 0.342660
# [Epoch : 8 / Iters : 21000/24912] => D_loss : 1.976417 / G_GAN_loss : 0.923605 / KL_div : 0.065396 / img_recon_loss : 0.425959 / z_recon_loss : 0.611911
# [Epoch : 8 / Iters : 22000/24912] => D_loss : 2.056637 / G_GAN_loss : 1.027043 / KL_div : 0.037236 / img_recon_loss : 0.236802 / z_recon_loss : 0.249886
# [Epoch : 8 / Iters : 23000/24912] => D_loss : 1.814568 / G_GAN_loss : 1.338084 / KL_div : 0.067789 / img_recon_loss : 0.822745 / z_recon_loss : 0.166006
# [Epoch : 8 / Iters : 24000/24912] => D_loss : 1.929036 / G_GAN_loss : 0.862896 / KL_div : 0.051775 / img_recon_loss : 0.743560 / z_recon_loss : 0.485140
# [Epoch : 9 / Iters : 0/24912] => D_loss : 1.897969 / G_GAN_loss : 1.245153 / KL_div : 0.090607 / img_recon_loss : 0.757031 / z_recon_loss : 0.361991
# [Epoch : 9 / Iters : 1000/24912] => D_loss : 1.880861 / G_GAN_loss : 0.972752 / KL_div : 0.051614 / img_recon_loss : 0.552096 / z_recon_loss : 0.243790
# [Epoch : 9 / Iters : 2000/24912] => D_loss : 2.012224 / G_GAN_loss : 1.228919 / KL_div : 0.083435 / img_recon_loss : 0.775954 / z_recon_loss : 0.326709
# [Epoch : 9 / Iters : 3000/24912] => D_loss : 1.972853 / G_GAN_loss : 1.637443 / KL_div : 0.055007 / img_recon_loss : 0.860397 / z_recon_loss : 0.384419
# [Epoch : 9 / Iters : 4000/24912] => D_loss : 1.692470 / G_GAN_loss : 1.107298 / KL_div : 0.073247 / img_recon_loss : 0.950407 / z_recon_loss : 0.436988
# [Epoch : 9 / Iters : 5000/24912] => D_loss : 2.215987 / G_GAN_loss : 1.186830 / KL_div : 0.059715 / img_recon_loss : 0.493045 / z_recon_loss : 0.243872
# [Epoch : 9 / Iters : 6000/24912] => D_loss : 1.889970 / G_GAN_loss : 1.158288 / KL_div : 0.083398 / img_recon_loss : 0.941480 / z_recon_loss : 0.319192
# [Epoch : 9 / Iters : 7000/24912] => D_loss : 1.577625 / G_GAN_loss : 1.255062 / KL_div : 0.079399 / img_recon_loss : 0.886478 / z_recon_loss : 0.359331
# [Epoch : 9 / Iters : 8000/24912] => D_loss : 1.704398 / G_GAN_loss : 1.274918 / KL_div : 0.065909 / img_recon_loss : 0.860732 / z_recon_loss : 0.236545
# [Epoch : 9 / Iters : 9000/24912] => D_loss : 1.545776 / G_GAN_loss : 1.768803 / KL_div : 0.088181 / img_recon_loss : 1.233987 / z_recon_loss : 0.197969
# [Epoch : 9 / Iters : 10000/24912] => D_loss : 2.029666 / G_GAN_loss : 1.009002 / KL_div : 0.125911 / img_recon_loss : 1.201221 / z_recon_loss : 0.430972
# [Epoch : 9 / Iters : 11000/24912] => D_loss : 2.163416 / G_GAN_loss : 1.123232 / KL_div : 0.103907 / img_recon_loss : 0.542251 / z_recon_loss : 0.321369
# [Epoch : 9 / Iters : 12000/24912] => D_loss : 2.035585 / G_GAN_loss : 1.099657 / KL_div : 0.060715 / img_recon_loss : 0.762760 / z_recon_loss : 0.289408
# [Epoch : 9 / Iters : 13000/24912] => D_loss : 1.878655 / G_GAN_loss : 1.311051 / KL_div : 0.061102 / img_recon_loss : 0.437063 / z_recon_loss : 0.316929
# [Epoch : 9 / Iters : 14000/24912] => D_loss : 2.163519 / G_GAN_loss : 1.202399 / KL_div : 0.047105 / img_recon_loss : 0.396113 / z_recon_loss : 0.137486
# [Epoch : 9 / Iters : 15000/24912] => D_loss : 1.908833 / G_GAN_loss : 1.194457 / KL_div : 0.097738 / img_recon_loss : 1.815431 / z_recon_loss : 0.260090
# [Epoch : 9 / Iters : 16000/24912] => D_loss : 1.543392 / G_GAN_loss : 1.991151 / KL_div : 0.124379 / img_recon_loss : 1.173128 / z_recon_loss : 0.390819
# [Epoch : 9 / Iters : 17000/24912] => D_loss : 1.902954 / G_GAN_loss : 1.252480 / KL_div : 0.075324 / img_recon_loss : 0.699395 / z_recon_loss : 0.250629
# [Epoch : 9 / Iters : 18000/24912] => D_loss : 1.944536 / G_GAN_loss : 1.125119 / KL_div : 0.076816 / img_recon_loss : 0.710088 / z_recon_loss : 0.329106
# [Epoch : 9 / Iters : 19000/24912] => D_loss : 1.358475 / G_GAN_loss : 1.523847 / KL_div : 0.073403 / img_recon_loss : 0.627046 / z_recon_loss : 0.235112
# [Epoch : 9 / Iters : 20000/24912] => D_loss : 1.983594 / G_GAN_loss : 0.956756 / KL_div : 0.045249 / img_recon_loss : 0.437470 / z_recon_loss : 0.430519
# [Epoch : 9 / Iters : 21000/24912] => D_loss : 2.003389 / G_GAN_loss : 1.167075 / KL_div : 0.057453 / img_recon_loss : 0.460713 / z_recon_loss : 0.253933
# [Epoch : 9 / Iters : 22000/24912] => D_loss : 1.639707 / G_GAN_loss : 1.054391 / KL_div : 0.105862 / img_recon_loss : 1.731608 / z_recon_loss : 0.311964
# [Epoch : 9 / Iters : 23000/24912] => D_loss : 2.103296 / G_GAN_loss : 1.197998 / KL_div : 0.045451 / img_recon_loss : 0.294126 / z_recon_loss : 0.315690
# [Epoch : 9 / Iters : 24000/24912] => D_loss : 1.750320 / G_GAN_loss : 1.159330 / KL_div : 0.097307 / img_recon_loss : 1.071149 / z_recon_loss : 0.327730
# [Epoch : 10 / Iters : 0/24912] => D_loss : 1.753916 / G_GAN_loss : 1.257777 / KL_div : 0.059033 / img_recon_loss : 0.498071 / z_recon_loss : 0.173217
# [Epoch : 10 / Iters : 1000/24912] => D_loss : 2.104878 / G_GAN_loss : 1.231809 / KL_div : 0.043906 / img_recon_loss : 0.270759 / z_recon_loss : 0.387525
# [Epoch : 10 / Iters : 2000/24912] => D_loss : 1.852741 / G_GAN_loss : 1.185784 / KL_div : 0.101485 / img_recon_loss : 1.099015 / z_recon_loss : 0.285489
# [Epoch : 10 / Iters : 3000/24912] => D_loss : 1.655392 / G_GAN_loss : 1.033186 / KL_div : 0.106557 / img_recon_loss : 0.546384 / z_recon_loss : 0.366539
# [Epoch : 10 / Iters : 4000/24912] => D_loss : 2.110164 / G_GAN_loss : 1.038680 / KL_div : 0.152922 / img_recon_loss : 0.447450 / z_recon_loss : 0.330782
# [Epoch : 10 / Iters : 5000/24912] => D_loss : 2.072496 / G_GAN_loss : 1.022279 / KL_div : 0.066035 / img_recon_loss : 0.758581 / z_recon_loss : 0.403387
# [Epoch : 10 / Iters : 6000/24912] => D_loss : 1.951779 / G_GAN_loss : 0.942749 / KL_div : 0.088754 / img_recon_loss : 0.897372 / z_recon_loss : 0.380097
# [Epoch : 10 / Iters : 7000/24912] => D_loss : 1.570974 / G_GAN_loss : 1.392192 / KL_div : 0.121016 / img_recon_loss : 1.042458 / z_recon_loss : 0.264178
# [Epoch : 10 / Iters : 8000/24912] => D_loss : 2.140121 / G_GAN_loss : 1.344418 / KL_div : 0.128328 / img_recon_loss : 0.705521 / z_recon_loss : 0.427131
# [Epoch : 10 / Iters : 9000/24912] => D_loss : 1.867578 / G_GAN_loss : 1.297491 / KL_div : 0.100988 / img_recon_loss : 0.881850 / z_recon_loss : 0.374345
# [Epoch : 10 / Iters : 10000/24912] => D_loss : 2.254721 / G_GAN_loss : 1.139236 / KL_div : 0.061127 / img_recon_loss : 0.566815 / z_recon_loss : 0.296865
# [Epoch : 10 / Iters : 11000/24912] => D_loss : 1.697140 / G_GAN_loss : 1.176721 / KL_div : 0.082457 / img_recon_loss : 1.415716 / z_recon_loss : 0.300987
# [Epoch : 10 / Iters : 12000/24912] => D_loss : 2.218215 / G_GAN_loss : 1.165829 / KL_div : 0.105947 / img_recon_loss : 1.160553 / z_recon_loss : 0.183733
# [Epoch : 10 / Iters : 13000/24912] => D_loss : 1.520450 / G_GAN_loss : 1.311293 / KL_div : 0.064053 / img_recon_loss : 1.588740 / z_recon_loss : 0.260392
# [Epoch : 10 / Iters : 14000/24912] => D_loss : 1.881889 / G_GAN_loss : 1.029381 / KL_div : 0.062729 / img_recon_loss : 1.263291 / z_recon_loss : 0.352869
# [Epoch : 10 / Iters : 15000/24912] => D_loss : 1.955212 / G_GAN_loss : 1.314533 / KL_div : 0.071666 / img_recon_loss : 0.755821 / z_recon_loss : 0.242424
# [Epoch : 10 / Iters : 16000/24912] => D_loss : 1.869394 / G_GAN_loss : 1.048301 / KL_div : 0.090005 / img_recon_loss : 1.083417 / z_recon_loss : 0.434215
# [Epoch : 10 / Iters : 17000/24912] => D_loss : 1.750147 / G_GAN_loss : 1.144337 / KL_div : 0.064972 / img_recon_loss : 0.510068 / z_recon_loss : 0.200574
# [Epoch : 10 / Iters : 18000/24912] => D_loss : 2.003373 / G_GAN_loss : 1.069510 / KL_div : 0.069004 / img_recon_loss : 0.753311 / z_recon_loss : 0.268379
# [Epoch : 10 / Iters : 19000/24912] => D_loss : 1.687987 / G_GAN_loss : 1.264683 / KL_div : 0.063352 / img_recon_loss : 0.693847 / z_recon_loss : 0.496299
# [Epoch : 10 / Iters : 20000/24912] => D_loss : 1.799174 / G_GAN_loss : 0.895716 / KL_div : 0.090745 / img_recon_loss : 0.690056 / z_recon_loss : 0.431927
# [Epoch : 10 / Iters : 21000/24912] => D_loss : 1.987100 / G_GAN_loss : 1.154219 / KL_div : 0.106510 / img_recon_loss : 0.940945 / z_recon_loss : 0.249357
# [Epoch : 10 / Iters : 22000/24912] => D_loss : 1.878337 / G_GAN_loss : 0.999925 / KL_div : 0.055192 / img_recon_loss : 0.447163 / z_recon_loss : 0.180405
# [Epoch : 10 / Iters : 23000/24912] => D_loss : 1.744502 / G_GAN_loss : 0.906791 / KL_div : 0.077600 / img_recon_loss : 1.139401 / z_recon_loss : 0.369599
# [Epoch : 10 / Iters : 24000/24912] => D_loss : 1.944618 / G_GAN_loss : 1.135106 / KL_div : 0.072825 / img_recon_loss : 0.642489 / z_recon_loss : 0.105898
# [Epoch : 11 / Iters : 0/24912] => D_loss : 1.990382 / G_GAN_loss : 0.979666 / KL_div : 0.067413 / img_recon_loss : 0.683998 / z_recon_loss : 0.319180
# [Epoch : 11 / Iters : 1000/24912] => D_loss : 1.773522 / G_GAN_loss : 1.016369 / KL_div : 0.072281 / img_recon_loss : 0.489482 / z_recon_loss : 0.346104
# [Epoch : 11 / Iters : 2000/24912] => D_loss : 1.966730 / G_GAN_loss : 1.558311 / KL_div : 0.063315 / img_recon_loss : 0.868137 / z_recon_loss : 0.235100
# [Epoch : 11 / Iters : 3000/24912] => D_loss : 2.200895 / G_GAN_loss : 1.003325 / KL_div : 0.073266 / img_recon_loss : 0.720324 / z_recon_loss : 0.415475
# [Epoch : 11 / Iters : 4000/24912] => D_loss : 1.745249 / G_GAN_loss : 1.266314 / KL_div : 0.068998 / img_recon_loss : 0.570846 / z_recon_loss : 0.479868
# [Epoch : 11 / Iters : 5000/24912] => D_loss : 2.292974 / G_GAN_loss : 0.925575 / KL_div : 0.193371 / img_recon_loss : 0.642583 / z_recon_loss : 0.209856
# [Epoch : 11 / Iters : 6000/24912] => D_loss : 1.664715 / G_GAN_loss : 0.969307 / KL_div : 0.086043 / img_recon_loss : 1.018049 / z_recon_loss : 0.346147
# [Epoch : 11 / Iters : 7000/24912] => D_loss : 2.273100 / G_GAN_loss : 1.256908 / KL_div : 0.094187 / img_recon_loss : 0.777207 / z_recon_loss : 0.184419
# [Epoch : 11 / Iters : 8000/24912] => D_loss : 1.971529 / G_GAN_loss : 1.203797 / KL_div : 0.090610 / img_recon_loss : 0.613932 / z_recon_loss : 0.161056
# [Epoch : 11 / Iters : 9000/24912] => D_loss : 1.994856 / G_GAN_loss : 0.948565 / KL_div : 0.061759 / img_recon_loss : 0.741481 / z_recon_loss : 0.517906
# [Epoch : 11 / Iters : 10000/24912] => D_loss : 2.049987 / G_GAN_loss : 1.114752 / KL_div : 0.056242 / img_recon_loss : 0.499823 / z_recon_loss : 0.324382
# [Epoch : 11 / Iters : 11000/24912] => D_loss : 1.949901 / G_GAN_loss : 1.179568 / KL_div : 0.074904 / img_recon_loss : 1.014628 / z_recon_loss : 0.338499
# [Epoch : 11 / Iters : 12000/24912] => D_loss : 1.993548 / G_GAN_loss : 1.305593 / KL_div : 0.067243 / img_recon_loss : 0.567778 / z_recon_loss : 0.309959
# [Epoch : 11 / Iters : 13000/24912] => D_loss : 2.088398 / G_GAN_loss : 1.234648 / KL_div : 0.082256 / img_recon_loss : 1.503301 / z_recon_loss : 0.490921
# [Epoch : 11 / Iters : 14000/24912] => D_loss : 1.792315 / G_GAN_loss : 1.342486 / KL_div : 0.068504 / img_recon_loss : 0.563925 / z_recon_loss : 0.397998
# [Epoch : 11 / Iters : 15000/24912] => D_loss : 2.032321 / G_GAN_loss : 0.825660 / KL_div : 0.067544 / img_recon_loss : 0.688247 / z_recon_loss : 0.406818
# [Epoch : 11 / Iters : 16000/24912] => D_loss : 1.725956 / G_GAN_loss : 1.452384 / KL_div : 0.113046 / img_recon_loss : 1.488924 / z_recon_loss : 0.306468
# [Epoch : 11 / Iters : 17000/24912] => D_loss : 1.897042 / G_GAN_loss : 1.148578 / KL_div : 0.084865 / img_recon_loss : 0.548087 / z_recon_loss : 0.427263
# [Epoch : 11 / Iters : 18000/24912] => D_loss : 2.043436 / G_GAN_loss : 0.991046 / KL_div : 0.071124 / img_recon_loss : 0.723590 / z_recon_loss : 0.324581
# [Epoch : 11 / Iters : 19000/24912] => D_loss : 1.933326 / G_GAN_loss : 1.138177 / KL_div : 0.098402 / img_recon_loss : 0.537440 / z_recon_loss : 0.284938
# [Epoch : 11 / Iters : 20000/24912] => D_loss : 2.212799 / G_GAN_loss : 0.955905 / KL_div : 0.062720 / img_recon_loss : 0.583279 / z_recon_loss : 0.390643
# [Epoch : 11 / Iters : 21000/24912] => D_loss : 1.785781 / G_GAN_loss : 1.243750 / KL_div : 0.084390 / img_recon_loss : 0.758981 / z_recon_loss : 0.415946
# [Epoch : 11 / Iters : 22000/24912] => D_loss : 1.755759 / G_GAN_loss : 1.249485 / KL_div : 0.088437 / img_recon_loss : 1.171426 / z_recon_loss : 0.240628
# [Epoch : 11 / Iters : 23000/24912] => D_loss : 2.105589 / G_GAN_loss : 1.209806 / KL_div : 0.060779 / img_recon_loss : 0.419024 / z_recon_loss : 0.282072
# [Epoch : 11 / Iters : 24000/24912] => D_loss : 1.746472 / G_GAN_loss : 1.439091 / KL_div : 0.092814 / img_recon_loss : 0.573856 / z_recon_loss : 0.351320
# [Epoch : 12 / Iters : 0/24912] => D_loss : 1.874107 / G_GAN_loss : 1.102705 / KL_div : 0.073077 / img_recon_loss : 0.957539 / z_recon_loss : 0.281166
# [Epoch : 12 / Iters : 1000/24912] => D_loss : 1.712808 / G_GAN_loss : 1.403944 / KL_div : 0.054768 / img_recon_loss : 0.579097 / z_recon_loss : 0.173871
# [Epoch : 12 / Iters : 2000/24912] => D_loss : 2.087150 / G_GAN_loss : 0.980054 / KL_div : 0.069168 / img_recon_loss : 0.804826 / z_recon_loss : 0.433246
# [Epoch : 12 / Iters : 3000/24912] => D_loss : 1.746924 / G_GAN_loss : 1.147828 / KL_div : 0.082941 / img_recon_loss : 0.746119 / z_recon_loss : 0.200135
# [Epoch : 12 / Iters : 4000/24912] => D_loss : 1.951522 / G_GAN_loss : 1.147347 / KL_div : 0.089071 / img_recon_loss : 0.780083 / z_recon_loss : 0.340593
# [Epoch : 12 / Iters : 5000/24912] => D_loss : 1.682820 / G_GAN_loss : 1.056920 / KL_div : 0.061717 / img_recon_loss : 0.947147 / z_recon_loss : 0.336045
# [Epoch : 12 / Iters : 6000/24912] => D_loss : 1.736881 / G_GAN_loss : 1.206379 / KL_div : 0.084091 / img_recon_loss : 0.746053 / z_recon_loss : 0.137517
# [Epoch : 12 / Iters : 7000/24912] => D_loss : 2.116738 / G_GAN_loss : 1.145147 / KL_div : 0.123855 / img_recon_loss : 0.627282 / z_recon_loss : 0.407043
# [Epoch : 12 / Iters : 8000/24912] => D_loss : 1.834514 / G_GAN_loss : 1.061828 / KL_div : 0.061059 / img_recon_loss : 0.459183 / z_recon_loss : 0.170383
# [Epoch : 12 / Iters : 9000/24912] => D_loss : 1.963037 / G_GAN_loss : 1.206627 / KL_div : 0.148290 / img_recon_loss : 1.363512 / z_recon_loss : 0.359181
# [Epoch : 12 / Iters : 10000/24912] => D_loss : 2.071327 / G_GAN_loss : 1.137208 / KL_div : 0.070757 / img_recon_loss : 0.934659 / z_recon_loss : 0.389570
# [Epoch : 12 / Iters : 11000/24912] => D_loss : 1.724961 / G_GAN_loss : 1.521522 / KL_div : 0.078358 / img_recon_loss : 2.118192 / z_recon_loss : 0.419868
# [Epoch : 12 / Iters : 12000/24912] => D_loss : 1.644540 / G_GAN_loss : 1.074670 / KL_div : 0.087299 / img_recon_loss : 1.476018 / z_recon_loss : 0.231504
# [Epoch : 12 / Iters : 13000/24912] => D_loss : 1.816064 / G_GAN_loss : 1.267762 / KL_div : 0.083176 / img_recon_loss : 0.891338 / z_recon_loss : 0.320949
# [Epoch : 12 / Iters : 14000/24912] => D_loss : 2.213135 / G_GAN_loss : 1.137226 / KL_div : 0.055585 / img_recon_loss : 0.600970 / z_recon_loss : 0.269592
# [Epoch : 12 / Iters : 15000/24912] => D_loss : 1.998868 / G_GAN_loss : 1.264823 / KL_div : 0.121485 / img_recon_loss : 0.718680 / z_recon_loss : 0.251285
# [Epoch : 12 / Iters : 16000/24912] => D_loss : 1.754049 / G_GAN_loss : 1.684857 / KL_div : 0.112571 / img_recon_loss : 0.702251 / z_recon_loss : 0.228904
# [Epoch : 12 / Iters : 17000/24912] => D_loss : 1.806226 / G_GAN_loss : 1.405666 / KL_div : 0.093511 / img_recon_loss : 0.698116 / z_recon_loss : 0.179253
# [Epoch : 12 / Iters : 18000/24912] => D_loss : 1.732437 / G_GAN_loss : 1.167769 / KL_div : 0.090274 / img_recon_loss : 0.700477 / z_recon_loss : 0.133657
# [Epoch : 12 / Iters : 19000/24912] => D_loss : 1.762109 / G_GAN_loss : 1.182220 / KL_div : 0.068002 / img_recon_loss : 0.672758 / z_recon_loss : 0.215616
# [Epoch : 12 / Iters : 20000/24912] => D_loss : 1.994834 / G_GAN_loss : 1.345065 / KL_div : 0.097040 / img_recon_loss : 0.679382 / z_recon_loss : 0.508184
# [Epoch : 12 / Iters : 21000/24912] => D_loss : 2.018141 / G_GAN_loss : 1.053094 / KL_div : 0.067105 / img_recon_loss : 0.846471 / z_recon_loss : 0.267993
# [Epoch : 12 / Iters : 22000/24912] => D_loss : 2.081714 / G_GAN_loss : 0.977596 / KL_div : 0.057938 / img_recon_loss : 0.331799 / z_recon_loss : 0.531895
# [Epoch : 12 / Iters : 23000/24912] => D_loss : 1.986593 / G_GAN_loss : 0.969839 / KL_div : 0.089372 / img_recon_loss : 0.600249 / z_recon_loss : 0.343148
# [Epoch : 12 / Iters : 24000/24912] => D_loss : 2.130163 / G_GAN_loss : 0.907766 / KL_div : 0.072616 / img_recon_loss : 1.089758 / z_recon_loss : 0.223994
# [Epoch : 13 / Iters : 0/24912] => D_loss : 1.828473 / G_GAN_loss : 1.121706 / KL_div : 0.110625 / img_recon_loss : 0.929442 / z_recon_loss : 0.232793
# [Epoch : 13 / Iters : 1000/24912] => D_loss : 1.974355 / G_GAN_loss : 0.948314 / KL_div : 0.048826 / img_recon_loss : 0.505145 / z_recon_loss : 0.291739
# [Epoch : 13 / Iters : 2000/24912] => D_loss : 2.031669 / G_GAN_loss : 1.084676 / KL_div : 0.071265 / img_recon_loss : 0.815080 / z_recon_loss : 0.243780
# [Epoch : 13 / Iters : 3000/24912] => D_loss : 1.915650 / G_GAN_loss : 1.020317 / KL_div : 0.092959 / img_recon_loss : 0.555471 / z_recon_loss : 0.437835
# [Epoch : 13 / Iters : 4000/24912] => D_loss : 2.001682 / G_GAN_loss : 1.264644 / KL_div : 0.122786 / img_recon_loss : 0.504183 / z_recon_loss : 0.285026
# [Epoch : 13 / Iters : 5000/24912] => D_loss : 2.080724 / G_GAN_loss : 1.356511 / KL_div : 0.070357 / img_recon_loss : 0.567112 / z_recon_loss : 0.265494
# [Epoch : 13 / Iters : 6000/24912] => D_loss : 1.953906 / G_GAN_loss : 1.026065 / KL_div : 0.112969 / img_recon_loss : 0.422630 / z_recon_loss : 0.436995
# [Epoch : 13 / Iters : 7000/24912] => D_loss : 1.973535 / G_GAN_loss : 1.317758 / KL_div : 0.076139 / img_recon_loss : 0.494606 / z_recon_loss : 0.392443
# [Epoch : 13 / Iters : 8000/24912] => D_loss : 1.737896 / G_GAN_loss : 1.203555 / KL_div : 0.079556 / img_recon_loss : 0.739544 / z_recon_loss : 0.237256
# [Epoch : 13 / Iters : 9000/24912] => D_loss : 1.969023 / G_GAN_loss : 0.998860 / KL_div : 0.070794 / img_recon_loss : 0.798268 / z_recon_loss : 0.324812
# [Epoch : 13 / Iters : 10000/24912] => D_loss : 1.809118 / G_GAN_loss : 1.136779 / KL_div : 0.100813 / img_recon_loss : 0.443773 / z_recon_loss : 0.271966
# [Epoch : 13 / Iters : 11000/24912] => D_loss : 1.914769 / G_GAN_loss : 1.074951 / KL_div : 0.094549 / img_recon_loss : 0.311042 / z_recon_loss : 0.346311
# [Epoch : 13 / Iters : 12000/24912] => D_loss : 2.099475 / G_GAN_loss : 1.179569 / KL_div : 0.079922 / img_recon_loss : 0.618433 / z_recon_loss : 0.251798
# [Epoch : 13 / Iters : 13000/24912] => D_loss : 1.815401 / G_GAN_loss : 1.223197 / KL_div : 0.061526 / img_recon_loss : 0.885622 / z_recon_loss : 0.266564
# ...
# [Epoch : 18 / Iters : 2000/24912] => D_loss : 1.928165 / G_GAN_loss : 1.306739 / KL_div : 0.152063 / img_recon_loss : 0.985290 / z_recon_loss : 0.244097
# [Epoch : 18 / Iters : 3000/24912] => D_loss : 1.941279 / G_GAN_loss : 1.088749 / KL_div : 0.079006 / img_recon_loss : 1.111145 / z_recon_loss : 0.252016
# [Epoch : 18 / Iters : 4000/24912] => D_loss : 2.072338 / G_GAN_loss : 1.028715 / KL_div : 0.078683 / img_recon_loss : 0.928087 / z_recon_loss : 0.332500
# [Epoch : 18 / Iters : 6000/24912] => D_loss : 2.044812 / G_GAN_loss : 0.958725 / KL_div : 0.063621 / img_recon_loss : 0.514034 / z_recon_loss : 0.266633
# [Epoch : 18 / Iters : 7000/24912] => D_loss : 1.677370 / G_GAN_loss : 1.129994 / KL_div : 0.083060 / img_recon_loss : 1.366383 / z_recon_loss : 0.220757
# [Epoch : 18 / Iters : 8000/24912] => D_loss : 2.073735 / G_GAN_loss : 0.920242 / KL_div : 0.045156 / img_recon_loss : 0.336219 / z_recon_loss : 0.227927
# [Epoch : 18 / Iters : 9000/24912] => D_loss : 1.822137 / G_GAN_loss : 1.342276 / KL_div : 0.053611 / img_recon_loss : 0.420848 / z_recon_loss : 0.327007
# [Epoch : 18 / Iters : 10000/24912] => D_loss : 1.935140 / G_GAN_loss : 1.134310 / KL_div : 0.111852 / img_recon_loss : 0.772468 / z_recon_loss : 0.365200
# [Epoch : 18 / Iters : 11000/24912] => D_loss : 1.961246 / G_GAN_loss : 1.115086 / KL_div : 0.073031 / img_recon_loss : 0.685716 / z_recon_loss : 0.317659
# [Epoch : 18 / Iters : 12000/24912] => D_loss : 2.083831 / G_GAN_loss : 1.024708 / KL_div : 0.079081 / img_recon_loss : 0.516661 / z_recon_loss : 0.564901
# [Epoch : 18 / Iters : 13000/24912] => D_loss : 1.898313 / G_GAN_loss : 1.054459 / KL_div : 0.107894 / img_recon_loss : 0.704600 / z_recon_loss : 0.192709
# [Epoch : 18 / Iters : 14000/24912] => D_loss : 1.946187 / G_GAN_loss : 1.264561 / KL_div : 0.057832 / img_recon_loss : 0.455562 / z_recon_loss : 0.171283
# [Epoch : 18 / Iters : 15000/24912] => D_loss : 2.027666 / G_GAN_loss : 1.518459 / KL_div : 0.072788 / img_recon_loss : 0.385258 / z_recon_loss : 0.358422
# [Epoch : 18 / Iters : 16000/24912] => D_loss : 1.987304 / G_GAN_loss : 1.128210 / KL_div : 0.058556 / img_recon_loss : 0.342563 / z_recon_loss : 0.373983
# [Epoch : 18 / Iters : 17000/24912] => D_loss : 1.719123 / G_GAN_loss : 1.262364 / KL_div : 0.099340 / img_recon_loss : 1.197393 / z_recon_loss : 0.362404
# [Epoch : 18 / Iters : 18000/24912] => D_loss : 2.283005 / G_GAN_loss : 0.983237 / KL_div : 0.108446 / img_recon_loss : 0.815093 / z_recon_loss : 0.251990
# [Epoch : 18 / Iters : 19000/24912] => D_loss : 1.916867 / G_GAN_loss : 1.232043 / KL_div : 0.062331 / img_recon_loss : 0.389533 / z_recon_loss : 0.318635
# [Epoch : 18 / Iters : 20000/24912] => D_loss : 1.982582 / G_GAN_loss : 0.903207 / KL_div : 0.076730 / img_recon_loss : 1.208623 / z_recon_loss : 0.391516
# [Epoch : 18 / Iters : 21000/24912] => D_loss : 1.925082 / G_GAN_loss : 1.159137 / KL_div : 0.071993 / img_recon_loss : 0.478249 / z_recon_loss : 0.223647
# [Epoch : 18 / Iters : 22000/24912] => D_loss : 1.884009 / G_GAN_loss : 1.188558 / KL_div : 0.072914 / img_recon_loss : 0.784595 / z_recon_loss : 0.313376
# [Epoch : 18 / Iters : 23000/24912] => D_loss : 1.924500 / G_GAN_loss : 1.064989 / KL_div : 0.065228 / img_recon_loss : 1.030040 / z_recon_loss : 0.275131
# [Epoch : 18 / Iters : 24000/24912] => D_loss : 1.939780 / G_GAN_loss : 1.221239 / KL_div : 0.136365 / img_recon_loss : 0.874478 / z_recon_loss : 0.244039
# [Epoch : 19 / Iters : 0/24912] => D_loss : 1.883039 / G_GAN_loss : 1.082544 / KL_div : 0.077214 / img_recon_loss : 0.712812 / z_recon_loss : 0.213233
# [Epoch : 19 / Iters : 1000/24912] => D_loss : 1.960837 / G_GAN_loss : 1.684692 / KL_div : 0.069526 / img_recon_loss : 0.551655 / z_recon_loss : 0.423894
# [Epoch : 19 / Iters : 2000/24912] => D_loss : 1.889768 / G_GAN_loss : 1.092632 / KL_div : 0.075460 / img_recon_loss : 0.513405 / z_recon_loss : 0.189534
# [Epoch : 19 / Iters : 3000/24912] => D_loss : 1.838086 / G_GAN_loss : 1.124994 / KL_div : 0.063363 / img_recon_loss : 0.335582 / z_recon_loss : 0.252442
# [Epoch : 19 / Iters : 4000/24912] => D_loss : 1.742156 / G_GAN_loss : 0.954347 / KL_div : 0.075941 / img_recon_loss : 0.908775 / z_recon_loss : 0.144518
# [Epoch : 19 / Iters : 5000/24912] => D_loss : 1.939537 / G_GAN_loss : 0.920112 / KL_div : 0.060857 / img_recon_loss : 0.636038 / z_recon_loss : 0.328351
# [Epoch : 19 / Iters : 6000/24912] => D_loss : 1.814948 / G_GAN_loss : 1.203803 / KL_div : 0.110153 / img_recon_loss : 1.919220 / z_recon_loss : 0.296426
# [Epoch : 19 / Iters : 7000/24912] => D_loss : 1.668834 / G_GAN_loss : 1.948621 / KL_div : 0.093629 / img_recon_loss : 0.716498 / z_recon_loss : 0.316065
# [Epoch : 19 / Iters : 8000/24912] => D_loss : 1.761637 / G_GAN_loss : 1.246236 / KL_div : 0.082984 / img_recon_loss : 0.967644 / z_recon_loss : 0.380449
# [Epoch : 19 / Iters : 9000/24912] => D_loss : 2.175149 / G_GAN_loss : 1.167221 / KL_div : 0.078769 / img_recon_loss : 0.763132 / z_recon_loss : 0.292972
# [Epoch : 19 / Iters : 10000/24912] => D_loss : 1.933409 / G_GAN_loss : 2.225986 / KL_div : 0.100960 / img_recon_loss : 0.617514 / z_recon_loss : 0.383673
# [Epoch : 19 / Iters : 11000/24912] => D_loss : 1.875866 / G_GAN_loss : 1.239172 / KL_div : 0.115412 / img_recon_loss : 0.723222 / z_recon_loss : 0.306537
# [Epoch : 19 / Iters : 12000/24912] => D_loss : 2.005300 / G_GAN_loss : 1.102522 / KL_div : 0.080728 / img_recon_loss : 0.561019 / z_recon_loss : 0.214971
# [Epoch : 19 / Iters : 13000/24912] => D_loss : 1.882819 / G_GAN_loss : 1.334169 / KL_div : 0.104896 / img_recon_loss : 0.656297 / z_recon_loss : 0.343220
# [Epoch : 19 / Iters : 14000/24912] => D_loss : 1.624769 / G_GAN_loss : 1.487329 / KL_div : 0.097586 / img_recon_loss : 1.162561 / z_recon_loss : 0.184772
# [Epoch : 19 / Iters : 15000/24912] => D_loss : 1.492141 / G_GAN_loss : 1.000565 / KL_div : 0.100994 / img_recon_loss : 0.758270 / z_recon_loss : 0.436916
# [Epoch : 19 / Iters : 16000/24912] => D_loss : 1.802765 / G_GAN_loss : 1.400756 / KL_div : 0.161760 / img_recon_loss : 0.840783 / z_recon_loss : 0.195764
# [Epoch : 19 / Iters : 17000/24912] => D_loss : 2.076823 / G_GAN_loss : 1.500222 / KL_div : 0.094407 / img_recon_loss : 0.609016 / z_recon_loss : 0.326037
# [Epoch : 19 / Iters : 18000/24912] => D_loss : 1.560628 / G_GAN_loss : 1.327649 / KL_div : 0.069588 / img_recon_loss : 0.791910 / z_recon_loss : 0.215617
# [Epoch : 19 / Iters : 19000/24912] => D_loss : 1.939207 / G_GAN_loss : 1.421969 / KL_div : 0.118945 / img_recon_loss : 0.714941 / z_recon_loss : 0.284889
# [Epoch : 19 / Iters : 20000/24912] => D_loss : 2.014730 / G_GAN_loss : 1.011985 / KL_div : 0.081852 / img_recon_loss : 1.037419 / z_recon_loss : 0.327512
# [Epoch : 19 / Iters : 21000/24912] => D_loss : 1.599209 / G_GAN_loss : 1.407749 / KL_div : 0.159529 / img_recon_loss : 0.952240 / z_recon_loss : 0.277193
# [Epoch : 19 / Iters : 22000/24912] => D_loss : 2.044316 / G_GAN_loss : 1.243195 / KL_div : 0.069997 / img_recon_loss : 0.601717 / z_recon_loss : 0.309217
# [Epoch : 19 / Iters : 23000/24912] => D_loss : 1.707535 / G_GAN_loss : 1.312903 / KL_div : 0.108197 / img_recon_loss : 1.556413 / z_recon_loss : 0.181452
# [Epoch : 19 / Iters : 24000/24912] => D_loss : 1.841387 / G_GAN_loss : 1.575882 / KL_div : 0.060431 / img_recon_loss : 0.469458 / z_recon_loss : 0.195838
# [Epoch : 20 / Iters : 0/24912] => D_loss : 1.649007 / G_GAN_loss : 0.927641 / KL_div : 0.105646 / img_recon_loss : 0.657974 / z_recon_loss : 0.228768
# [Epoch : 20 / Iters : 1000/24912] => D_loss : 1.635430 / G_GAN_loss : 0.988033 / KL_div : 0.073565 / img_recon_loss : 0.827415 / z_recon_loss : 0.373672
# [Epoch : 20 / Iters : 2000/24912] => D_loss : 1.909045 / G_GAN_loss : 1.103692 / KL_div : 0.075813 / img_recon_loss : 0.539437 / z_recon_loss : 0.283637
# [Epoch : 20 / Iters : 3000/24912] => D_loss : 2.128336 / G_GAN_loss : 1.116898 / KL_div : 0.055752 / img_recon_loss : 0.370337 / z_recon_loss : 0.170307
# [Epoch : 20 / Iters : 4000/24912] => D_loss : 1.602407 / G_GAN_loss : 1.410819 / KL_div : 0.090663 / img_recon_loss : 0.436649 / z_recon_loss : 0.390202
# [Epoch : 20 / Iters : 5000/24912] => D_loss : 1.445581 / G_GAN_loss : 1.398039 / KL_div : 0.080405 / img_recon_loss : 1.194784 / z_recon_loss : 0.402390
# [Epoch : 20 / Iters : 6000/24912] => D_loss : 1.904478 / G_GAN_loss : 1.034948 / KL_div : 0.083926 / img_recon_loss : 1.369494 / z_recon_loss : 0.343415
# [Epoch : 20 / Iters : 7000/24912] => D_loss : 1.807940 / G_GAN_loss : 1.182498 / KL_div : 0.066983 / img_recon_loss : 0.891903 / z_recon_loss : 0.312664
# [Epoch : 20 / Iters : 8000/24912] => D_loss : 1.772807 / G_GAN_loss : 1.422530 / KL_div : 0.075911 / img_recon_loss : 0.686633 / z_recon_loss : 0.191751
# [Epoch : 20 / Iters : 9000/24912] => D_loss : 2.216429 / G_GAN_loss : 1.334676 / KL_div : 0.101005 / img_recon_loss : 0.571559 / z_recon_loss : 0.200025
# [Epoch : 20 / Iters : 10000/24912] => D_loss : 1.836589 / G_GAN_loss : 1.635221 / KL_div : 0.065799 / img_recon_loss : 0.583530 / z_recon_loss : 0.400877
# [Epoch : 20 / Iters : 11000/24912] => D_loss : 1.841171 / G_GAN_loss : 0.809344 / KL_div : 0.085818 / img_recon_loss : 0.634087 / z_recon_loss : 0.392368
# [Epoch : 20 / Iters : 12000/24912] => D_loss : 1.850833 / G_GAN_loss : 1.275510 / KL_div : 0.088489 / img_recon_loss : 0.998211 / z_recon_loss : 0.332531
# [Epoch : 20 / Iters : 13000/24912] => D_loss : 1.970487 / G_GAN_loss : 1.215244 / KL_div : 0.092297 / img_recon_loss : 1.298357 / z_recon_loss : 0.256384
# [Epoch : 20 / Iters : 14000/24912] => D_loss : 1.362746 / G_GAN_loss : 1.037199 / KL_div : 0.096765 / img_recon_loss : 1.031890 / z_recon_loss : 0.226729
# [Epoch : 20 / Iters : 15000/24912] => D_loss : 1.934073 / G_GAN_loss : 1.176131 / KL_div : 0.072267 / img_recon_loss : 0.694314 / z_recon_loss : 0.229572
# [Epoch : 20 / Iters : 16000/24912] => D_loss : 1.914967 / G_GAN_loss : 0.951851 / KL_div : 0.128770 / img_recon_loss : 0.509386 / z_recon_loss : 0.299146
# [Epoch : 20 / Iters : 17000/24912] => D_loss : 2.085118 / G_GAN_loss : 1.182284 / KL_div : 0.060245 / img_recon_loss : 0.563802 / z_recon_loss : 0.194118
# [Epoch : 20 / Iters : 18000/24912] => D_loss : 1.542733 / G_GAN_loss : 1.007383 / KL_div : 0.103940 / img_recon_loss : 1.402657 / z_recon_loss : 0.383948
# [Epoch : 20 / Iters : 19000/24912] => D_loss : 1.799009 / G_GAN_loss : 1.149503 / KL_div : 0.089040 / img_recon_loss : 1.548937 / z_recon_loss : 0.250842
# [Epoch : 20 / Iters : 20000/24912] => D_loss : 1.420035 / G_GAN_loss : 1.653180 / KL_div : 0.085065 / img_recon_loss : 1.216422 / z_recon_loss : 0.283854
# [Epoch : 20 / Iters : 21000/24912] => D_loss : 2.040811 / G_GAN_loss : 0.900970 / KL_div : 0.040498 / img_recon_loss : 0.329238 / z_recon_loss : 0.435691
# [Epoch : 20 / Iters : 22000/24912] => D_loss : 2.098425 / G_GAN_loss : 1.499812 / KL_div : 0.069138 / img_recon_loss : 0.684129 / z_recon_loss : 0.277625
# [Epoch : 20 / Iters : 23000/24912] => D_loss : 1.895185 / G_GAN_loss : 1.141300 / KL_div : 0.074440 / img_recon_loss : 0.633579 / z_recon_loss : 0.277438
# [Epoch : 20 / Iters : 24000/24912] => D_loss : 1.865741 / G_GAN_loss : 1.052489 / KL_div : 0.069922 / img_recon_loss : 0.696172 / z_recon_loss : 0.383827
# [Epoch : 21 / Iters : 0/24912] => D_loss : 1.907899 / G_GAN_loss : 1.300985 / KL_div : 0.063045 / img_recon_loss : 0.558527 / z_recon_loss : 0.308422
# [Epoch : 21 / Iters : 1000/24912] => D_loss : 1.575127 / G_GAN_loss : 1.154651 / KL_div : 0.091222 / img_recon_loss : 1.212987 / z_recon_loss : 0.281798
# [Epoch : 21 / Iters : 2000/24912] => D_loss : 1.585081 / G_GAN_loss : 1.176727 / KL_div : 0.063021 / img_recon_loss : 0.422668 / z_recon_loss : 0.141751
# [Epoch : 21 / Iters : 3000/24912] => D_loss : 1.635128 / G_GAN_loss : 1.086834 / KL_div : 0.092092 / img_recon_loss : 1.122933 / z_recon_loss : 0.208733
# [Epoch : 21 / Iters : 4000/24912] => D_loss : 1.855991 / G_GAN_loss : 1.126390 / KL_div : 0.093740 / img_recon_loss : 0.865186 / z_recon_loss : 0.246368
# [Epoch : 21 / Iters : 5000/24912] => D_loss : 1.752335 / G_GAN_loss : 1.180928 / KL_div : 0.114973 / img_recon_loss : 1.031403 / z_recon_loss : 0.269374
# [Epoch : 21 / Iters : 6000/24912] => D_loss : 1.840185 / G_GAN_loss : 1.125061 / KL_div : 0.101827 / img_recon_loss : 0.647047 / z_recon_loss : 0.200260
# [Epoch : 21 / Iters : 7000/24912] => D_loss : 2.178285 / G_GAN_loss : 1.056190 / KL_div : 0.075939 / img_recon_loss : 0.566969 / z_recon_loss : 0.307970
# [Epoch : 21 / Iters : 8000/24912] => D_loss : 1.573551 / G_GAN_loss : 1.078243 / KL_div : 0.123422 / img_recon_loss : 0.908841 / z_recon_loss : 0.137894
# [Epoch : 21 / Iters : 9000/24912] => D_loss : 2.104736 / G_GAN_loss : 1.087520 / KL_div : 0.084424 / img_recon_loss : 0.497040 / z_recon_loss : 0.396078
# [Epoch : 21 / Iters : 10000/24912] => D_loss : 1.989002 / G_GAN_loss : 1.008265 / KL_div : 0.099654 / img_recon_loss : 1.089024 / z_recon_loss : 0.255903
# [Epoch : 21 / Iters : 11000/24912] => D_loss : 1.256774 / G_GAN_loss : 1.618688 / KL_div : 0.093535 / img_recon_loss : 1.543120 / z_recon_loss : 0.292328
# [Epoch : 21 / Iters : 12000/24912] => D_loss : 2.118107 / G_GAN_loss : 0.936054 / KL_div : 0.097705 / img_recon_loss : 0.693324 / z_recon_loss : 0.189431
# [Epoch : 21 / Iters : 13000/24912] => D_loss : 1.917962 / G_GAN_loss : 1.007474 / KL_div : 0.078607 / img_recon_loss : 0.690275 / z_recon_loss : 0.261778
# [Epoch : 21 / Iters : 14000/24912] => D_loss : 1.649586 / G_GAN_loss : 1.298442 / KL_div : 0.109135 / img_recon_loss : 1.292950 / z_recon_loss : 0.360130
# [Epoch : 21 / Iters : 15000/24912] => D_loss : 1.952272 / G_GAN_loss : 1.067950 / KL_div : 0.135913 / img_recon_loss : 0.606378 / z_recon_loss : 0.103358
# [Epoch : 21 / Iters : 16000/24912] => D_loss : 1.871135 / G_GAN_loss : 1.081461 / KL_div : 0.114061 / img_recon_loss : 0.652359 / z_recon_loss : 0.348428
# [Epoch : 21 / Iters : 17000/24912] => D_loss : 1.758169 / G_GAN_loss : 0.985544 / KL_div : 0.131817 / img_recon_loss : 0.913984 / z_recon_loss : 0.331976
# [Epoch : 21 / Iters : 18000/24912] => D_loss : 1.506147 / G_GAN_loss : 0.807866 / KL_div : 0.054480 / img_recon_loss : 0.625847 / z_recon_loss : 0.307474
# [Epoch : 21 / Iters : 19000/24912] => D_loss : 1.904266 / G_GAN_loss : 1.030074 / KL_div : 0.091303 / img_recon_loss : 0.874318 / z_recon_loss : 0.146982
# [Epoch : 21 / Iters : 20000/24912] => D_loss : 1.726205 / G_GAN_loss : 1.825239 / KL_div : 0.080160 / img_recon_loss : 0.725874 / z_recon_loss : 0.217757
# [Epoch : 21 / Iters : 21000/24912] => D_loss : 1.892735 / G_GAN_loss : 1.020290 / KL_div : 0.070689 / img_recon_loss : 0.762815 / z_recon_loss : 0.154398
# [Epoch : 21 / Iters : 22000/24912] => D_loss : 1.772667 / G_GAN_loss : 0.963163 / KL_div : 0.103872 / img_recon_loss : 0.683394 / z_recon_loss : 0.324953
# [Epoch : 21 / Iters : 23000/24912] => D_loss : 1.822368 / G_GAN_loss : 1.234666 / KL_div : 0.057557 / img_recon_loss : 0.412500 / z_recon_loss : 0.355569
# [Epoch : 21 / Iters : 24000/24912] => D_loss : 2.201782 / G_GAN_loss : 1.061153 / KL_div : 0.070186 / img_recon_loss : 0.520649 / z_recon_loss : 0.278028
# [Epoch : 22 / Iters : 0/24912] => D_loss : 1.846363 / G_GAN_loss : 1.154869 / KL_div : 0.067443 / img_recon_loss : 0.495617 / z_recon_loss : 0.212921
# [Epoch : 22 / Iters : 1000/24912] => D_loss : 2.111249 / G_GAN_loss : 1.209302 / KL_div : 0.123319 / img_recon_loss : 0.588687 / z_recon_loss : 0.203204
# [Epoch : 22 / Iters : 2000/24912] => D_loss : 1.541066 / G_GAN_loss : 2.248145 / KL_div : 0.085496 / img_recon_loss : 0.750734 / z_recon_loss : 0.202508
# [Epoch : 22 / Iters : 3000/24912] => D_loss : 1.803861 / G_GAN_loss : 1.571037 / KL_div : 0.077421 / img_recon_loss : 0.915297 / z_recon_loss : 0.284553
# [Epoch : 22 / Iters : 4000/24912] => D_loss : 1.835812 / G_GAN_loss : 1.137642 / KL_div : 0.074417 / img_recon_loss : 0.573591 / z_recon_loss : 0.214922
# [Epoch : 22 / Iters : 5000/24912] => D_loss : 1.805736 / G_GAN_loss : 1.235220 / KL_div : 0.086876 / img_recon_loss : 0.459545 / z_recon_loss : 0.464423
# [Epoch : 22 / Iters : 6000/24912] => D_loss : 1.506453 / G_GAN_loss : 1.034563 / KL_div : 0.087236 / img_recon_loss : 0.923606 / z_recon_loss : 0.171715
