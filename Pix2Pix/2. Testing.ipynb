# %% [markdown]
# ## 1. Import Libs

# %%
from __future__ import print_function
import argparse
import os

import torch
from torch.autograd import Variable
import torchvision.transforms as transforms
from util import is_image_file, load_img, save_img

# %% [markdown]
# ## 2. Setting Hyperparameters

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--dataset', required=False, default='facades', help='facades')
parser.add_argument('--model', required=False, type=str, default='save_model/facades/netG_model_epoch_200.pkl', help='model file to use')
parser.add_argument('--cuda', action='store_true', default=True, help='use cuda')
params = parser.parse_args([])
print(params)
# Out:
# Namespace(cuda=True, dataset='facades', model='save_model/facades/netG_model_epoch_200.pkl')

# %% [markdown]
# ## 3. Testing

# %%
netG = torch.load(params.model)
image_dir = 'dataset/{}/test/a/'.format(params.dataset)
image_filenames = [x for x in os.listdir(image_dir) if is_image_file(x)]

# Preprocessing
transform_list = [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, .5), (.5, .5, .5))]
transform = transforms.Compose(transform_list)

for image_name in image_filenames:
    img = load_img(image_dir + image_name)
    img = transform(img)
    
    # 모델에 맞는 텐서구조로 변경
    input = Variable(img, volatile=True).view(1, -1, 256, 256)
    
    if params.cuda:
        netG = netG.cuda()
        input = input.cuda()
    
    out = netG(input)
    out = out.cpu()
    out_img = out.data[0]
    
    # generate한 이미지를 저장하는 파일을 생성
    if not os.path.exists(os.path.join("result", params.dataset)):
        os.mkdir(os.path.join('result', params.dataset))
    save_img(out_img, "result/{}/{}".format(params.dataset, image_name))
# Out:
# Image saved as result/facades/cmp_b0223.jpg
# Image saved as result/facades/cmp_b0241.jpg
# Image saved as result/facades/cmp_b0329.jpg
# Image saved as result/facades/cmp_b0358.jpg
# Image saved as result/facades/cmp_b0299.jpg
# Image saved as result/facades/cmp_b0303.jpg
# Image saved as result/facades/cmp_b0342.jpg
# Image saved as result/facades/cmp_b0263.jpg
# Image saved as result/facades/cmp_b0346.jpg
# Image saved as result/facades/cmp_b0272.jpg
# Image saved as result/facades/cmp_b0269.jpg
# Image saved as result/facades/cmp_b0203.jpg
# Image saved as result/facades/cmp_b0320.jpg
# Image saved as result/facades/cmp_b0246.jpg
# Image saved as result/facades/cmp_b0275.jpg
# Image saved as result/facades/cmp_b0276.jpg
# Image saved as result/facades/cmp_b0262.jpg
# Image saved as result/facades/cmp_b0338.jpg
# Image saved as result/facades/cmp_b0274.jpg
# Image saved as result/facades/cmp_b0287.jpg
# Image saved as result/facades/cmp_b0270.jpg
# Image saved as result/facades/cmp_b0264.jpg
# Image saved as result/facades/cmp_b0335.jpg
# Image saved as result/facades/cmp_b0378.jpg
# Image saved as result/facades/cmp_b0252.jpg
# Image saved as result/facades/cmp_b0221.jpg
# Image saved as result/facades/cmp_b0377.jpg
# Image saved as result/facades/cmp_b0228.jpg
# Image saved as result/facades/cmp_b0234.jpg
# Image saved as result/facades/cmp_b0249.jpg
# Image saved as result/facades/cmp_b0211.jpg
# Image saved as result/facades/cmp_b0307.jpg
# Image saved as result/facades/cmp_b0251.jpg
# Image saved as result/facades/cmp_b0372.jpg
# Image saved as result/facades/cmp_b0364.jpg
# Image saved as result/facades/cmp_b0227.jpg
# Image saved as result/facades/cmp_b0214.jpg
# Image saved as result/facades/cmp_b0295.jpg
# Image saved as result/facades/cmp_b0216.jpg
# Image saved as result/facades/cmp_b0271.jpg
# Image saved as result/facades/cmp_b0348.jpg
# Image saved as result/facades/cmp_b0362.jpg
# Image saved as result/facades/cmp_b0240.jpg
# Image saved as result/facades/cmp_b0217.jpg
# Image saved as result/facades/cmp_b0280.jpg
# Image saved as result/facades/cmp_b0265.jpg
# Image saved as result/facades/cmp_b0239.jpg
# Image saved as result/facades/cmp_b0286.jpg
# Image saved as result/facades/cmp_b0312.jpg
# Image saved as result/facades/cmp_b0250.jpg
# Image saved as result/facades/cmp_b0349.jpg
# Image saved as result/facades/cmp_b0267.jpg
# Image saved as result/facades/cmp_b0318.jpg
# Image saved as result/facades/cmp_b0347.jpg
# Image saved as result/facades/cmp_b0273.jpg
# Image saved as result/facades/cmp_b0248.jpg
# Image saved as result/facades/cmp_b0360.jpg
# Image saved as result/facades/cmp_b0229.jpg
# Image saved as result/facades/cmp_b0298.jpg
# Image saved as result/facades/cmp_b0288.jpg
# Image saved as result/facades/cmp_b0206.jpg
# Image saved as result/facades/cmp_b0373.jpg
# Image saved as result/facades/cmp_b0305.jpg
# Image saved as result/facades/cmp_b0242.jpg
# Image saved as result/facades/cmp_b0369.jpg
# Image saved as result/facades/cmp_b0215.jpg
# Image saved as result/facades/cmp_b0334.jpg
# Image saved as result/facades/cmp_b0208.jpg
# Image saved as result/facades/cmp_b0336.jpg
# Image saved as result/facades/cmp_b0257.jpg
# Image saved as result/facades/cmp_b0254.jpg
# Image saved as result/facades/cmp_b0266.jpg
# Image saved as result/facades/cmp_b0225.jpg
# Image saved as result/facades/cmp_b0330.jpg
# Image saved as result/facades/cmp_b0317.jpg
# Image saved as result/facades/cmp_b0353.jpg
# Image saved as result/facades/cmp_b0321.jpg
# Image saved as result/facades/cmp_b0339.jpg
# Image saved as result/facades/cmp_b0363.jpg
# Image saved as result/facades/cmp_b0328.jpg
# Image saved as result/facades/cmp_b0308.jpg
# Image saved as result/facades/cmp_b0236.jpg
# Image saved as result/facades/cmp_b0337.jpg
# Image saved as result/facades/cmp_b0314.jpg
# Image saved as result/facades/cmp_b0311.jpg
# Image saved as result/facades/cmp_b0344.jpg
# Image saved as result/facades/cmp_b0351.jpg
# Image saved as result/facades/cmp_b0260.jpg
# Image saved as result/facades/cmp_b0325.jpg
# Image saved as result/facades/cmp_b0310.jpg
# Image saved as result/facades/cmp_b0212.jpg
# Image saved as result/facades/cmp_b0224.jpg
# Image saved as result/facades/cmp_b0333.jpg
# Image saved as result/facades/cmp_b0283.jpg
# Image saved as result/facades/cmp_b0279.jpg
# Image saved as result/facades/cmp_b0370.jpg
# Image saved as result/facades/cmp_b0207.jpg
# Image saved as result/facades/cmp_b0282.jpg
# Image saved as result/facades/cmp_b0297.jpg
# Image saved as result/facades/cmp_b0243.jpg
# Image saved as result/facades/cmp_b0313.jpg
# Image saved as result/facades/cmp_b0357.jpg
# Image saved as result/facades/cmp_b0218.jpg
# Image saved as result/facades/cmp_b0253.jpg
# Image saved as result/facades/cmp_b0367.jpg
# Image saved as result/facades/cmp_b0331.jpg
# Image saved as result/facades/cmp_b0352.jpg
# Image saved as result/facades/cmp_b0233.jpg
# Image saved as result/facades/cmp_b0209.jpg
# Image saved as result/facades/cmp_b0291.jpg
# Image saved as result/facades/cmp_b0232.jpg
# Image saved as result/facades/cmp_b0285.jpg
# Image saved as result/facades/cmp_b0365.jpg
# Image saved as result/facades/cmp_b0376.jpg
# Image saved as result/facades/cmp_b0355.jpg
# Image saved as result/facades/cmp_b0201.jpg
# Image saved as result/facades/cmp_b0294.jpg
# Image saved as result/facades/cmp_b0293.jpg
# Image saved as result/facades/cmp_b0292.jpg
# Image saved as result/facades/cmp_b0366.jpg
# Image saved as result/facades/cmp_b0359.jpg
# Image saved as result/facades/cmp_b0304.jpg
# Image saved as result/facades/cmp_b0290.jpg
# Image saved as result/facades/cmp_b0343.jpg
# Image saved as result/facades/cmp_b0340.jpg
# Image saved as result/facades/cmp_b0247.jpg
# Image saved as result/facades/cmp_b0213.jpg
# Image saved as result/facades/cmp_b0323.jpg
# Image saved as result/facades/cmp_b0222.jpg
# Image saved as result/facades/cmp_b0259.jpg
# Image saved as result/facades/cmp_b0226.jpg
# Image saved as result/facades/cmp_b0324.jpg
# Image saved as result/facades/cmp_b0256.jpg
# Image saved as result/facades/cmp_b0204.jpg
# Image saved as result/facades/cmp_b0202.jpg
# Image saved as result/facades/cmp_b0306.jpg
# Image saved as result/facades/cmp_b0268.jpg
# Image saved as result/facades/cmp_b0341.jpg
# Image saved as result/facades/cmp_b0301.jpg
# Image saved as result/facades/cmp_b0371.jpg
# Image saved as result/facades/cmp_b0368.jpg
# Image saved as result/facades/cmp_b0332.jpg
# Image saved as result/facades/cmp_b0219.jpg
# Image saved as result/facades/cmp_b0296.jpg
# Image saved as result/facades/cmp_b0322.jpg
# Image saved as result/facades/cmp_b0284.jpg
# Image saved as result/facades/cmp_b0230.jpg
# Image saved as result/facades/cmp_b0278.jpg
# Image saved as result/facades/cmp_b0327.jpg
# Image saved as result/facades/cmp_b0255.jpg
# Image saved as result/facades/cmp_b0277.jpg
# Image saved as result/facades/cmp_b0374.jpg
# Image saved as result/facades/cmp_b0309.jpg
# Image saved as result/facades/cmp_b0326.jpg
# Image saved as result/facades/cmp_b0210.jpg
# Image saved as result/facades/cmp_b0356.jpg
# Image saved as result/facades/cmp_b0361.jpg
# Image saved as result/facades/cmp_b0238.jpg
# Image saved as result/facades/cmp_b0258.jpg
# Image saved as result/facades/cmp_b0316.jpg
# Image saved as result/facades/cmp_b0281.jpg
# Image saved as result/facades/cmp_b0235.jpg
# Image saved as result/facades/cmp_b0354.jpg
# Image saved as result/facades/cmp_b0220.jpg
# Image saved as result/facades/cmp_b0315.jpg
# Image saved as result/facades/cmp_b0237.jpg
# Image saved as result/facades/cmp_b0300.jpg
# Image saved as result/facades/cmp_b0375.jpg
# Image saved as result/facades/cmp_b0289.jpg
# Image saved as result/facades/cmp_b0345.jpg
# Image saved as result/facades/cmp_b0302.jpg
# Image saved as result/facades/cmp_b0245.jpg
# Image saved as result/facades/cmp_b0244.jpg
# Image saved as result/facades/cmp_b0205.jpg
# Image saved as result/facades/cmp_b0350.jpg
# Image saved as result/facades/cmp_b0261.jpg
# Image saved as result/facades/cmp_b0231.jpg
# Image saved as result/facades/cmp_b0319.jpg
